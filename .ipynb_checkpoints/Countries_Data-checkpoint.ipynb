# %%
import pandas as pd
import numpy as np
import requests
import json
from pandas.io.json import json_normalize

# %%
# URL for GET requests to retrieve global count data and all countries data
url1 = "https://coronavirus-19-api.herokuapp.com/all"
url2 = "https://coronavirus-19-api.herokuapp.com/countries"

# URL for GET requests to retrieve US States TestResults data
url3 = "https://covidtracking.com/api/states"

# %%
response = requests.get(url1)
response.json()
# Out:
# {'cases': 2358256, 'deaths': 161902, 'recovered': 606630}

# %%
Global_df = json_normalize(response.json(), errors='ignore')
Global_df
# Out:
#      cases  deaths  recovered
# 0  2358256  161902     606630

# %%
response = requests.get(url2)
response.json()
# Out:
# [{'country': 'North America',
#   'cases': 792769,
#   'todayCases': 1363,
#   'deaths': 41670,
#   'todayDeaths': 133,
#   'recovered': 83535,
#   'active': 667564,
#   'critical': 14660,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Europe',
#   'cases': 1079650,
#   'todayCases': 19614,
#   'deaths': 100794,
#   'todayDeaths': 1516,
#   'recovered': 305791,
#   'active': 673065,
#   'critical': 25711,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Asia',
#   'cases': 376860,
#   'todayCases': 6076,
#   'deaths': 14593,
#   'todayDeaths': 192,
#   'recovered': 178315,
#   'active': 183952,
#   'critical': 6357,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'South America',
#   'cases': 78207,
#   'todayCases': 234,
#   'deaths': 3665,
#   'todayDeaths': 12,
#   'recovered': 27698,
#   'active': 46844,
#   'critical': 7532,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Oceania',
#   'cases': 8134,
#   'todayCases': 29,
#   'deaths': 82,
#   'todayDeaths': 1,
#   'recovered': 5159,
#   'active': 2893,
#   'critical': 68,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Africa',
#   'cases': 21915,
#   'todayCases': 174,
#   'deaths': 1083,
#   'todayDeaths': 1,
#   'recovered': 5488,
#   'active': 15344,
#   'critical': 195,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': '',
#   'cases': 721,
#   'todayCases': 0,
#   'deaths': 15,
#   'todayDeaths': 0,
#   'recovered': 644,
#   'active': 62,
#   'critical': 7,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'World',
#   'cases': 2358256,
#   'todayCases': 27490,
#   'deaths': 161902,
#   'todayDeaths': 1855,
#   'recovered': 606630,
#   'active': 1589724,
#   'critical': 54530,
#   'casesPerOneMillion': 303,
#   'deathsPerOneMillion': 20,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'USA',
#   'cases': 739407,
#   'todayCases': 615,
#   'deaths': 39038,
#   'todayDeaths': 24,
#   'recovered': 68442,
#   'active': 631927,
#   'critical': 13551,
#   'casesPerOneMillion': 2234,
#   'deathsPerOneMillion': 118,
#   'totalTests': 3726454,
#   'testsPerOneMillion': 11258},
#  {'country': 'Spain',
#   'cases': 195944,
#   'todayCases': 1528,
#   'deaths': 20453,
#   'todayDeaths': 410,
#   'recovered': 77357,
#   'active': 98134,
#   'critical': 7371,
#   'casesPerOneMillion': 4191,
#   'deathsPerOneMillion': 437,
#   'totalTests': 930230,
#   'testsPerOneMillion': 19896},
#  {'country': 'Italy',
#   'cases': 175925,
#   'todayCases': 0,
#   'deaths': 23227,
#   'todayDeaths': 0,
#   'recovered': 44927,
#   'active': 107771,
#   'critical': 2733,
#   'casesPerOneMillion': 2910,
#   'deathsPerOneMillion': 384,
#   'totalTests': 1305833,
#   'testsPerOneMillion': 21598},
#  {'country': 'France',
#   'cases': 151793,
#   'todayCases': 0,
#   'deaths': 19323,
#   'todayDeaths': 0,
#   'recovered': 35983,
#   'active': 96487,
#   'critical': 5833,
#   'casesPerOneMillion': 2325,
#   'deathsPerOneMillion': 296,
#   'totalTests': 463662,
#   'testsPerOneMillion': 7103},
#  {'country': 'Germany',
#   'cases': 144033,
#   'todayCases': 309,
#   'deaths': 4545,
#   'todayDeaths': 7,
#   'recovered': 88000,
#   'active': 51488,
#   'critical': 2922,
#   'casesPerOneMillion': 1719,
#   'deathsPerOneMillion': 54,
#   'totalTests': 1728357,
#   'testsPerOneMillion': 20629},
#  {'country': 'UK',
#   'cases': 120067,
#   'todayCases': 5850,
#   'deaths': 16060,
#   'todayDeaths': 596,
#   'recovered': None,
#   'active': 103663,
#   'critical': 1559,
#   'casesPerOneMillion': 1769,
#   'deathsPerOneMillion': 237,
#   'totalTests': 482063,
#   'testsPerOneMillion': 7101},
#  {'country': 'Turkey',
#   'cases': 82329,
#   'todayCases': 0,
#   'deaths': 1890,
#   'todayDeaths': 0,
#   'recovered': 10453,
#   'active': 69986,
#   'critical': 1894,
#   'casesPerOneMillion': 976,
#   'deathsPerOneMillion': 22,
#   'totalTests': 598933,
#   'testsPerOneMillion': 7101},
#  {'country': 'Iran',
#   'cases': 82211,
#   'todayCases': 1343,
#   'deaths': 5118,
#   'todayDeaths': 87,
#   'recovered': 57023,
#   'active': 20070,
#   'critical': 3456,
#   'casesPerOneMillion': 979,
#   'deathsPerOneMillion': 61,
#   'totalTests': 341662,
#   'testsPerOneMillion': 4068},
#  {'country': 'Russia',
#   'cases': 42853,
#   'todayCases': 6060,
#   'deaths': 361,
#   'todayDeaths': 48,
#   'recovered': 3291,
#   'active': 39201,
#   'critical': 8,
#   'casesPerOneMillion': 294,
#   'deathsPerOneMillion': 2,
#   'totalTests': 1940000,
#   'testsPerOneMillion': 13294},
#  {'country': 'Belgium',
#   'cases': 38496,
#   'todayCases': 1313,
#   'deaths': 5683,
#   'todayDeaths': 230,
#   'recovered': 8757,
#   'active': 24056,
#   'critical': 1081,
#   'casesPerOneMillion': 3322,
#   'deathsPerOneMillion': 490,
#   'totalTests': 153778,
#   'testsPerOneMillion': 13269},
#  {'country': 'Brazil',
#   'cases': 36925,
#   'todayCases': 203,
#   'deaths': 2372,
#   'todayDeaths': 11,
#   'recovered': 14026,
#   'active': 20527,
#   'critical': 6634,
#   'casesPerOneMillion': 174,
#   'deathsPerOneMillion': 11,
#   'totalTests': 62985,
#   'testsPerOneMillion': 296},
#  {'country': 'Canada',
#   'cases': 33383,
#   'todayCases': 0,
#   'deaths': 1470,
#   'todayDeaths': 0,
#   'recovered': 11207,
#   'active': 20706,
#   'critical': 557,
#   'casesPerOneMillion': 885,
#   'deathsPerOneMillion': 39,
#   'totalTests': 516216,
#   'testsPerOneMillion': 13677},
#  {'country': 'Netherlands',
#   'cases': 32655,
#   'todayCases': 1066,
#   'deaths': 3684,
#   'todayDeaths': 83,
#   'recovered': 250,
#   'active': 28721,
#   'critical': 1279,
#   'casesPerOneMillion': 1906,
#   'deathsPerOneMillion': 215,
#   'totalTests': 154911,
#   'testsPerOneMillion': 9041},
#  {'country': 'Switzerland',
#   'cases': 27740,
#   'todayCases': 336,
#   'deaths': 1368,
#   'todayDeaths': 0,
#   'recovered': 17100,
#   'active': 9272,
#   'critical': 386,
#   'casesPerOneMillion': 3205,
#   'deathsPerOneMillion': 158,
#   'totalTests': 221263,
#   'testsPerOneMillion': 25566},
#  {'country': 'Portugal',
#   'cases': 20206,
#   'todayCases': 521,
#   'deaths': 714,
#   'todayDeaths': 27,
#   'recovered': 610,
#   'active': 18882,
#   'critical': 224,
#   'casesPerOneMillion': 1982,
#   'deathsPerOneMillion': 70,
#   'totalTests': 235878,
#   'testsPerOneMillion': 23133},
#  {'country': 'India',
#   'cases': 16365,
#   'todayCases': 0,
#   'deaths': 521,
#   'todayDeaths': 0,
#   'recovered': 2466,
#   'active': 13378,
#   'critical': 0,
#   'casesPerOneMillion': 12,
#   'deathsPerOneMillion': 0,
#   'totalTests': 372123,
#   'testsPerOneMillion': 270},
#  {'country': 'Ireland',
#   'cases': 14758,
#   'todayCases': 0,
#   'deaths': 571,
#   'todayDeaths': 0,
#   'recovered': 77,
#   'active': 14110,
#   'critical': 294,
#   'casesPerOneMillion': 2989,
#   'deathsPerOneMillion': 116,
#   'totalTests': 90646,
#   'testsPerOneMillion': 18358},
#  {'country': 'Austria',
#   'cases': 14696,
#   'todayCases': 25,
#   'deaths': 443,
#   'todayDeaths': 0,
#   'recovered': 10501,
#   'active': 3752,
#   'critical': 204,
#   'casesPerOneMillion': 1632,
#   'deathsPerOneMillion': 49,
#   'totalTests': 179243,
#   'testsPerOneMillion': 19902},
#  {'country': 'Peru',
#   'cases': 14420,
#   'todayCases': 0,
#   'deaths': 348,
#   'todayDeaths': 0,
#   'recovered': 6684,
#   'active': 7388,
#   'critical': 117,
#   'casesPerOneMillion': 437,
#   'deathsPerOneMillion': 11,
#   'totalTests': 135895,
#   'testsPerOneMillion': 4122},
#  {'country': 'Sweden',
#   'cases': 14385,
#   'todayCases': 563,
#   'deaths': 1540,
#   'todayDeaths': 29,
#   'recovered': 550,
#   'active': 12295,
#   'critical': 450,
#   'casesPerOneMillion': 1424,
#   'deathsPerOneMillion': 152,
#   'totalTests': 74600,
#   'testsPerOneMillion': 7387},
#  {'country': 'Israel',
#   'cases': 13362,
#   'todayCases': 97,
#   'deaths': 171,
#   'todayDeaths': 7,
#   'recovered': 3564,
#   'active': 9627,
#   'critical': 156,
#   'casesPerOneMillion': 1544,
#   'deathsPerOneMillion': 20,
#   'totalTests': 187250,
#   'testsPerOneMillion': 21634},
#  {'country': 'S. Korea',
#   'cases': 10661,
#   'todayCases': 8,
#   'deaths': 234,
#   'todayDeaths': 2,
#   'recovered': 8042,
#   'active': 2385,
#   'critical': 55,
#   'casesPerOneMillion': 208,
#   'deathsPerOneMillion': 5,
#   'totalTests': 559109,
#   'testsPerOneMillion': 10905},
#  {'country': 'Japan',
#   'cases': 10296,
#   'todayCases': 0,
#   'deaths': 222,
#   'todayDeaths': 0,
#   'recovered': 1069,
#   'active': 9005,
#   'critical': 221,
#   'casesPerOneMillion': 81,
#   'deathsPerOneMillion': 2,
#   'totalTests': 111325,
#   'testsPerOneMillion': 880},
#  {'country': 'Chile',
#   'cases': 9730,
#   'todayCases': 0,
#   'deaths': 126,
#   'todayDeaths': 0,
#   'recovered': 4035,
#   'active': 5569,
#   'critical': 360,
#   'casesPerOneMillion': 509,
#   'deathsPerOneMillion': 7,
#   'totalTests': 108891,
#   'testsPerOneMillion': 5696},
#  {'country': 'Saudi Arabia',
#   'cases': 9362,
#   'todayCases': 1088,
#   'deaths': 97,
#   'todayDeaths': 5,
#   'recovered': 1398,
#   'active': 7867,
#   'critical': 78,
#   'casesPerOneMillion': 269,
#   'deathsPerOneMillion': 3,
#   'totalTests': 150000,
#   'testsPerOneMillion': 4309},
#  {'country': 'Poland',
#   'cases': 9082,
#   'todayCases': 340,
#   'deaths': 350,
#   'todayDeaths': 3,
#   'recovered': 1040,
#   'active': 7692,
#   'critical': 160,
#   'casesPerOneMillion': 240,
#   'deathsPerOneMillion': 9,
#   'totalTests': 204246,
#   'testsPerOneMillion': 5397},
#  {'country': 'Ecuador',
#   'cases': 9022,
#   'todayCases': 0,
#   'deaths': 456,
#   'todayDeaths': 0,
#   'recovered': 1008,
#   'active': 7558,
#   'critical': 168,
#   'casesPerOneMillion': 511,
#   'deathsPerOneMillion': 26,
#   'totalTests': 30922,
#   'testsPerOneMillion': 1753},
#  {'country': 'Romania',
#   'cases': 8746,
#   'todayCases': 328,
#   'deaths': 434,
#   'todayDeaths': 13,
#   'recovered': 1892,
#   'active': 6420,
#   'critical': 256,
#   'casesPerOneMillion': 455,
#   'deathsPerOneMillion': 23,
#   'totalTests': 93611,
#   'testsPerOneMillion': 4866},
#  {'country': 'Pakistan',
#   'cases': 7993,
#   'todayCases': 355,
#   'deaths': 159,
#   'todayDeaths': 16,
#   'recovered': 1868,
#   'active': 5966,
#   'critical': 46,
#   'casesPerOneMillion': 36,
#   'deathsPerOneMillion': 0,
#   'totalTests': 98522,
#   'testsPerOneMillion': 446},
#  {'country': 'Mexico',
#   'cases': 7497,
#   'todayCases': 622,
#   'deaths': 650,
#   'todayDeaths': 104,
#   'recovered': 2627,
#   'active': 4220,
#   'critical': 207,
#   'casesPerOneMillion': 58,
#   'deathsPerOneMillion': 5,
#   'totalTests': 49167,
#   'testsPerOneMillion': 381},
#  {'country': 'Denmark',
#   'cases': 7384,
#   'todayCases': 142,
#   'deaths': 355,
#   'todayDeaths': 9,
#   'recovered': 4141,
#   'active': 2888,
#   'critical': 76,
#   'casesPerOneMillion': 1275,
#   'deathsPerOneMillion': 61,
#   'totalTests': 94277,
#   'testsPerOneMillion': 16277},
#  {'country': 'Norway',
#   'cases': 7069,
#   'todayCases': 33,
#   'deaths': 165,
#   'todayDeaths': 1,
#   'recovered': 32,
#   'active': 6872,
#   'critical': 58,
#   'casesPerOneMillion': 1304,
#   'deathsPerOneMillion': 30,
#   'totalTests': 139668,
#   'testsPerOneMillion': 25763},
#  {'country': 'UAE',
#   'cases': 6781,
#   'todayCases': 479,
#   'deaths': 41,
#   'todayDeaths': 4,
#   'recovered': 1286,
#   'active': 5454,
#   'critical': 1,
#   'casesPerOneMillion': 686,
#   'deathsPerOneMillion': 4,
#   'totalTests': 767000,
#   'testsPerOneMillion': 77550},
#  {'country': 'Czechia',
#   'cases': 6657,
#   'todayCases': 51,
#   'deaths': 181,
#   'todayDeaths': 0,
#   'recovered': 1235,
#   'active': 5241,
#   'critical': 84,
#   'casesPerOneMillion': 622,
#   'deathsPerOneMillion': 17,
#   'totalTests': 168096,
#   'testsPerOneMillion': 15697},
#  {'country': 'Australia',
#   'cases': 6606,
#   'todayCases': 20,
#   'deaths': 70,
#   'todayDeaths': 0,
#   'recovered': 4230,
#   'active': 2306,
#   'critical': 48,
#   'casesPerOneMillion': 259,
#   'deathsPerOneMillion': 3,
#   'totalTests': 420996,
#   'testsPerOneMillion': 16510},
#  {'country': 'Singapore',
#   'cases': 6588,
#   'todayCases': 596,
#   'deaths': 11,
#   'todayDeaths': 0,
#   'recovered': 740,
#   'active': 5837,
#   'critical': 23,
#   'casesPerOneMillion': 1126,
#   'deathsPerOneMillion': 2,
#   'totalTests': 94796,
#   'testsPerOneMillion': 16203},
#  {'country': 'Indonesia',
#   'cases': 6575,
#   'todayCases': 327,
#   'deaths': 582,
#   'todayDeaths': 47,
#   'recovered': 686,
#   'active': 5307,
#   'critical': 0,
#   'casesPerOneMillion': 24,
#   'deathsPerOneMillion': 2,
#   'totalTests': 42219,
#   'testsPerOneMillion': 154},
#  {'country': 'Serbia',
#   'cases': 6318,
#   'todayCases': 324,
#   'deaths': 122,
#   'todayDeaths': 5,
#   'recovered': 753,
#   'active': 5443,
#   'critical': 120,
#   'casesPerOneMillion': 723,
#   'deathsPerOneMillion': 14,
#   'totalTests': 38701,
#   'testsPerOneMillion': 4429},
#  {'country': 'Philippines',
#   'cases': 6259,
#   'todayCases': 172,
#   'deaths': 409,
#   'todayDeaths': 12,
#   'recovered': 572,
#   'active': 5278,
#   'critical': 1,
#   'casesPerOneMillion': 57,
#   'deathsPerOneMillion': 4,
#   'totalTests': 59928,
#   'testsPerOneMillion': 547},
#  {'country': 'Ukraine',
#   'cases': 5449,
#   'todayCases': 343,
#   'deaths': 141,
#   'todayDeaths': 8,
#   'recovered': 347,
#   'active': 4961,
#   'critical': 45,
#   'casesPerOneMillion': 125,
#   'deathsPerOneMillion': 3,
#   'totalTests': 57111,
#   'testsPerOneMillion': 1306},
#  {'country': 'Qatar',
#   'cases': 5448,
#   'todayCases': 440,
#   'deaths': 8,
#   'todayDeaths': 0,
#   'recovered': 518,
#   'active': 4922,
#   'critical': 37,
#   'casesPerOneMillion': 1891,
#   'deathsPerOneMillion': 3,
#   'totalTests': 62538,
#   'testsPerOneMillion': 21707},
#  {'country': 'Malaysia',
#   'cases': 5389,
#   'todayCases': 84,
#   'deaths': 89,
#   'todayDeaths': 1,
#   'recovered': 3197,
#   'active': 2103,
#   'critical': 46,
#   'casesPerOneMillion': 167,
#   'deathsPerOneMillion': 3,
#   'totalTests': 103892,
#   'testsPerOneMillion': 3210},
#  {'country': 'Belarus',
#   'cases': 4779,
#   'todayCases': 0,
#   'deaths': 45,
#   'todayDeaths': 0,
#   'recovered': 342,
#   'active': 4392,
#   'critical': 65,
#   'casesPerOneMillion': 506,
#   'deathsPerOneMillion': 5,
#   'totalTests': 86813,
#   'testsPerOneMillion': 9187},
#  {'country': 'Dominican Republic',
#   'cases': 4335,
#   'todayCases': 0,
#   'deaths': 217,
#   'todayDeaths': 0,
#   'recovered': 312,
#   'active': 3806,
#   'critical': 146,
#   'casesPerOneMillion': 400,
#   'deathsPerOneMillion': 20,
#   'totalTests': 14373,
#   'testsPerOneMillion': 1325},
#  {'country': 'Panama',
#   'cases': 4273,
#   'todayCases': 63,
#   'deaths': 120,
#   'todayDeaths': 4,
#   'recovered': 140,
#   'active': 4013,
#   'critical': 96,
#   'casesPerOneMillion': 990,
#   'deathsPerOneMillion': 28,
#   'totalTests': 19091,
#   'testsPerOneMillion': 4425},
#  {'country': 'Finland',
#   'cases': 3783,
#   'todayCases': 102,
#   'deaths': 94,
#   'todayDeaths': 4,
#   'recovered': 1700,
#   'active': 1989,
#   'critical': 68,
#   'casesPerOneMillion': 683,
#   'deathsPerOneMillion': 17,
#   'totalTests': 57300,
#   'testsPerOneMillion': 10342},
#  {'country': 'Colombia',
#   'cases': 3621,
#   'todayCases': 0,
#   'deaths': 166,
#   'todayDeaths': 0,
#   'recovered': 691,
#   'active': 2764,
#   'critical': 98,
#   'casesPerOneMillion': 71,
#   'deathsPerOneMillion': 3,
#   'totalTests': 59002,
#   'testsPerOneMillion': 1160},
#  {'country': 'Luxembourg',
#   'cases': 3537,
#   'todayCases': 0,
#   'deaths': 72,
#   'todayDeaths': 0,
#   'recovered': 601,
#   'active': 2864,
#   'critical': 32,
#   'casesPerOneMillion': 5650,
#   'deathsPerOneMillion': 115,
#   'totalTests': 33252,
#   'testsPerOneMillion': 53120},
#  {'country': 'South Africa',
#   'cases': 3034,
#   'todayCases': 0,
#   'deaths': 52,
#   'todayDeaths': 0,
#   'recovered': 903,
#   'active': 2079,
#   'critical': 36,
#   'casesPerOneMillion': 51,
#   'deathsPerOneMillion': 0,
#   'totalTests': 108021,
#   'testsPerOneMillion': 1821},
#  {'country': 'Egypt',
#   'cases': 3032,
#   'todayCases': 0,
#   'deaths': 224,
#   'todayDeaths': 0,
#   'recovered': 701,
#   'active': 2107,
#   'critical': 0,
#   'casesPerOneMillion': 30,
#   'deathsPerOneMillion': 2,
#   'totalTests': 55000,
#   'testsPerOneMillion': 537},
#  {'country': 'Argentina',
#   'cases': 2839,
#   'todayCases': 0,
#   'deaths': 132,
#   'todayDeaths': 0,
#   'recovered': 685,
#   'active': 2022,
#   'critical': 127,
#   'casesPerOneMillion': 63,
#   'deathsPerOneMillion': 3,
#   'totalTests': 30942,
#   'testsPerOneMillion': 685},
#  {'country': 'Morocco',
#   'cases': 2820,
#   'todayCases': 135,
#   'deaths': 138,
#   'todayDeaths': 1,
#   'recovered': 322,
#   'active': 2360,
#   'critical': 1,
#   'casesPerOneMillion': 76,
#   'deathsPerOneMillion': 4,
#   'totalTests': 14189,
#   'testsPerOneMillion': 384},
#  {'country': 'Thailand',
#   'cases': 2765,
#   'todayCases': 32,
#   'deaths': 47,
#   'todayDeaths': 0,
#   'recovered': 1928,
#   'active': 790,
#   'critical': 61,
#   'casesPerOneMillion': 40,
#   'deathsPerOneMillion': 0,
#   'totalTests': 100498,
#   'testsPerOneMillion': 1440},
#  {'country': 'Algeria',
#   'cases': 2534,
#   'todayCases': 0,
#   'deaths': 367,
#   'todayDeaths': 0,
#   'recovered': 894,
#   'active': 1273,
#   'critical': 60,
#   'casesPerOneMillion': 58,
#   'deathsPerOneMillion': 8,
#   'totalTests': 6500,
#   'testsPerOneMillion': 148},
#  {'country': 'Bangladesh',
#   'cases': 2456,
#   'todayCases': 312,
#   'deaths': 91,
#   'todayDeaths': 7,
#   'recovered': 75,
#   'active': 2290,
#   'critical': 1,
#   'casesPerOneMillion': 15,
#   'deathsPerOneMillion': 0,
#   'totalTests': 23941,
#   'testsPerOneMillion': 145},
#  {'country': 'Moldova',
#   'cases': 2351,
#   'todayCases': 0,
#   'deaths': 62,
#   'todayDeaths': 5,
#   'recovered': 457,
#   'active': 1832,
#   'critical': 80,
#   'casesPerOneMillion': 583,
#   'deathsPerOneMillion': 15,
#   'totalTests': 9848,
#   'testsPerOneMillion': 2441},
#  {'country': 'Greece',
#   'cases': 2235,
#   'todayCases': 0,
#   'deaths': 110,
#   'todayDeaths': 0,
#   'recovered': 269,
#   'active': 1856,
#   'critical': 67,
#   'casesPerOneMillion': 214,
#   'deathsPerOneMillion': 11,
#   'totalTests': 53290,
#   'testsPerOneMillion': 5113},
#  {'country': 'Hungary',
#   'cases': 1916,
#   'todayCases': 82,
#   'deaths': 189,
#   'todayDeaths': 17,
#   'recovered': 250,
#   'active': 1477,
#   'critical': 61,
#   'casesPerOneMillion': 198,
#   'deathsPerOneMillion': 20,
#   'totalTests': 46353,
#   'testsPerOneMillion': 4798},
#  {'country': 'Kuwait',
#   'cases': 1915,
#   'todayCases': 164,
#   'deaths': 7,
#   'todayDeaths': 1,
#   'recovered': 305,
#   'active': 1603,
#   'critical': 38,
#   'casesPerOneMillion': 448,
#   'deathsPerOneMillion': 2,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Bahrain',
#   'cases': 1873,
#   'todayCases': 100,
#   'deaths': 7,
#   'todayDeaths': 0,
#   'recovered': 759,
#   'active': 1107,
#   'critical': 2,
#   'casesPerOneMillion': 1101,
#   'deathsPerOneMillion': 4,
#   'totalTests': 85126,
#   'testsPerOneMillion': 50028},
#  {'country': 'Croatia',
#   'cases': 1871,
#   'todayCases': 39,
#   'deaths': 47,
#   'todayDeaths': 8,
#   'recovered': 709,
#   'active': 1115,
#   'critical': 23,
#   'casesPerOneMillion': 456,
#   'deathsPerOneMillion': 11,
#   'totalTests': 24186,
#   'testsPerOneMillion': 5891},
#  {'country': 'Iceland',
#   'cases': 1760,
#   'todayCases': 0,
#   'deaths': 9,
#   'todayDeaths': 0,
#   'recovered': 1291,
#   'active': 460,
#   'critical': 3,
#   'casesPerOneMillion': 5158,
#   'deathsPerOneMillion': 26,
#   'totalTests': 41091,
#   'testsPerOneMillion': 120416},
#  {'country': 'Kazakhstan',
#   'cases': 1676,
#   'todayCases': 61,
#   'deaths': 17,
#   'todayDeaths': 0,
#   'recovered': 400,
#   'active': 1259,
#   'critical': 22,
#   'casesPerOneMillion': 89,
#   'deathsPerOneMillion': 0,
#   'totalTests': 100878,
#   'testsPerOneMillion': 5373},
#  {'country': 'Uzbekistan',
#   'cases': 1543,
#   'todayCases': 53,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 225,
#   'active': 1313,
#   'critical': 8,
#   'casesPerOneMillion': 46,
#   'deathsPerOneMillion': 0,
#   'totalTests': 136000,
#   'testsPerOneMillion': 4063},
#  {'country': 'Estonia',
#   'cases': 1528,
#   'todayCases': 16,
#   'deaths': 40,
#   'todayDeaths': 2,
#   'recovered': 164,
#   'active': 1324,
#   'critical': 10,
#   'casesPerOneMillion': 1152,
#   'deathsPerOneMillion': 30,
#   'totalTests': 40333,
#   'testsPerOneMillion': 30405},
#  {'country': 'Iraq',
#   'cases': 1513,
#   'todayCases': 0,
#   'deaths': 82,
#   'todayDeaths': 0,
#   'recovered': 953,
#   'active': 478,
#   'critical': 0,
#   'casesPerOneMillion': 38,
#   'deathsPerOneMillion': 2,
#   'totalTests': 53955,
#   'testsPerOneMillion': 1341},
#  {'country': 'New Zealand',
#   'cases': 1431,
#   'todayCases': 9,
#   'deaths': 12,
#   'todayDeaths': 1,
#   'recovered': 912,
#   'active': 507,
#   'critical': 18,
#   'casesPerOneMillion': 297,
#   'deathsPerOneMillion': 2,
#   'totalTests': 83224,
#   'testsPerOneMillion': 17258},
#  {'country': 'Azerbaijan',
#   'cases': 1398,
#   'todayCases': 25,
#   'deaths': 19,
#   'todayDeaths': 1,
#   'recovered': 712,
#   'active': 667,
#   'critical': 21,
#   'casesPerOneMillion': 138,
#   'deathsPerOneMillion': 2,
#   'totalTests': 95747,
#   'testsPerOneMillion': 9443},
#  {'country': 'Slovenia',
#   'cases': 1330,
#   'todayCases': 13,
#   'deaths': 74,
#   'todayDeaths': 4,
#   'recovered': 192,
#   'active': 1064,
#   'critical': 26,
#   'casesPerOneMillion': 640,
#   'deathsPerOneMillion': 36,
#   'totalTests': 41265,
#   'testsPerOneMillion': 19849},
#  {'country': 'Lithuania',
#   'cases': 1298,
#   'todayCases': 59,
#   'deaths': 35,
#   'todayDeaths': 2,
#   'recovered': 242,
#   'active': 1021,
#   'critical': 14,
#   'casesPerOneMillion': 477,
#   'deathsPerOneMillion': 13,
#   'totalTests': 64035,
#   'testsPerOneMillion': 23522},
#  {'country': 'Armenia',
#   'cases': 1291,
#   'todayCases': 43,
#   'deaths': 20,
#   'todayDeaths': 0,
#   'recovered': 545,
#   'active': 726,
#   'critical': 30,
#   'casesPerOneMillion': 436,
#   'deathsPerOneMillion': 7,
#   'totalTests': 12680,
#   'testsPerOneMillion': 4279},
#  {'country': 'Bosnia and Herzegovina',
#   'cases': 1285,
#   'todayCases': 17,
#   'deaths': 48,
#   'todayDeaths': 1,
#   'recovered': 347,
#   'active': 890,
#   'critical': 4,
#   'casesPerOneMillion': 392,
#   'deathsPerOneMillion': 15,
#   'totalTests': 17818,
#   'testsPerOneMillion': 5431},
#  {'country': 'Oman',
#   'cases': 1266,
#   'todayCases': 86,
#   'deaths': 6,
#   'todayDeaths': 0,
#   'recovered': 233,
#   'active': 1027,
#   'critical': 3,
#   'casesPerOneMillion': 248,
#   'deathsPerOneMillion': 1,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'North Macedonia',
#   'cases': 1207,
#   'todayCases': 37,
#   'deaths': 51,
#   'todayDeaths': 2,
#   'recovered': 179,
#   'active': 977,
#   'critical': 15,
#   'casesPerOneMillion': 579,
#   'deathsPerOneMillion': 24,
#   'totalTests': 11870,
#   'testsPerOneMillion': 5697},
#  {'country': 'Slovakia',
#   'cases': 1161,
#   'todayCases': 72,
#   'deaths': 12,
#   'todayDeaths': 1,
#   'recovered': 229,
#   'active': 920,
#   'critical': 10,
#   'casesPerOneMillion': 213,
#   'deathsPerOneMillion': 2,
#   'totalTests': 44276,
#   'testsPerOneMillion': 8110},
#  {'country': 'Hong Kong',
#   'cases': 1026,
#   'todayCases': 2,
#   'deaths': 4,
#   'todayDeaths': 0,
#   'recovered': 602,
#   'active': 420,
#   'critical': 8,
#   'casesPerOneMillion': 137,
#   'deathsPerOneMillion': 0,
#   'totalTests': 131786,
#   'testsPerOneMillion': 17579},
#  {'country': 'Cameroon',
#   'cases': 1017,
#   'todayCases': 0,
#   'deaths': 42,
#   'todayDeaths': 0,
#   'recovered': 305,
#   'active': 670,
#   'critical': 33,
#   'casesPerOneMillion': 38,
#   'deathsPerOneMillion': 2,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Afghanistan',
#   'cases': 993,
#   'todayCases': 60,
#   'deaths': 32,
#   'todayDeaths': 2,
#   'recovered': 131,
#   'active': 830,
#   'critical': 0,
#   'casesPerOneMillion': 26,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Cuba',
#   'cases': 986,
#   'todayCases': 0,
#   'deaths': 32,
#   'todayDeaths': 0,
#   'recovered': 227,
#   'active': 727,
#   'critical': 15,
#   'casesPerOneMillion': 87,
#   'deathsPerOneMillion': 3,
#   'totalTests': 25309,
#   'testsPerOneMillion': 2234},
#  {'country': 'Bulgaria',
#   'cases': 884,
#   'todayCases': 6,
#   'deaths': 42,
#   'todayDeaths': 1,
#   'recovered': 161,
#   'active': 681,
#   'critical': 35,
#   'casesPerOneMillion': 127,
#   'deathsPerOneMillion': 6,
#   'totalTests': 26417,
#   'testsPerOneMillion': 3802},
#  {'country': 'Tunisia',
#   'cases': 866,
#   'todayCases': 0,
#   'deaths': 37,
#   'todayDeaths': 0,
#   'recovered': 43,
#   'active': 786,
#   'critical': 33,
#   'casesPerOneMillion': 73,
#   'deathsPerOneMillion': 3,
#   'totalTests': 15332,
#   'testsPerOneMillion': 1297},
#  {'country': 'Ghana',
#   'cases': 834,
#   'todayCases': 0,
#   'deaths': 9,
#   'todayDeaths': 0,
#   'recovered': 99,
#   'active': 726,
#   'critical': 4,
#   'casesPerOneMillion': 27,
#   'deathsPerOneMillion': 0,
#   'totalTests': 60916,
#   'testsPerOneMillion': 1960},
#  {'country': 'Ivory Coast',
#   'cases': 801,
#   'todayCases': 0,
#   'deaths': 8,
#   'todayDeaths': 0,
#   'recovered': 239,
#   'active': 554,
#   'critical': 0,
#   'casesPerOneMillion': 30,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Cyprus',
#   'cases': 761,
#   'todayCases': 0,
#   'deaths': 12,
#   'todayDeaths': 0,
#   'recovered': 79,
#   'active': 670,
#   'critical': 8,
#   'casesPerOneMillion': 630,
#   'deathsPerOneMillion': 10,
#   'totalTests': 32284,
#   'testsPerOneMillion': 26739},
#  {'country': 'Djibouti',
#   'cases': 732,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 76,
#   'active': 654,
#   'critical': 0,
#   'casesPerOneMillion': 741,
#   'deathsPerOneMillion': 2,
#   'totalTests': 7486,
#   'testsPerOneMillion': 7577},
#  {'country': 'Latvia',
#   'cases': 727,
#   'todayCases': 15,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 88,
#   'active': 634,
#   'critical': 5,
#   'casesPerOneMillion': 385,
#   'deathsPerOneMillion': 3,
#   'totalTests': 35881,
#   'testsPerOneMillion': 19023},
#  {'country': 'Diamond Princess',
#   'cases': 712,
#   'todayCases': 0,
#   'deaths': 13,
#   'todayDeaths': 0,
#   'recovered': 644,
#   'active': 55,
#   'critical': 7,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Andorra',
#   'cases': 704,
#   'todayCases': 0,
#   'deaths': 35,
#   'todayDeaths': 0,
#   'recovered': 205,
#   'active': 464,
#   'critical': 17,
#   'casesPerOneMillion': 9111,
#   'deathsPerOneMillion': 453,
#   'totalTests': 1673,
#   'testsPerOneMillion': 21653},
#  {'country': 'Lebanon',
#   'cases': 673,
#   'todayCases': 1,
#   'deaths': 21,
#   'todayDeaths': 0,
#   'recovered': 99,
#   'active': 553,
#   'critical': 27,
#   'casesPerOneMillion': 99,
#   'deathsPerOneMillion': 3,
#   'totalTests': 20929,
#   'testsPerOneMillion': 3066},
#  {'country': 'Costa Rica',
#   'cases': 655,
#   'todayCases': 0,
#   'deaths': 4,
#   'todayDeaths': 0,
#   'recovered': 97,
#   'active': 554,
#   'critical': 10,
#   'casesPerOneMillion': 129,
#   'deathsPerOneMillion': 0,
#   'totalTests': 10138,
#   'testsPerOneMillion': 1990},
#  {'country': 'Niger',
#   'cases': 639,
#   'todayCases': 0,
#   'deaths': 19,
#   'todayDeaths': 0,
#   'recovered': 113,
#   'active': 507,
#   'critical': 0,
#   'casesPerOneMillion': 26,
#   'deathsPerOneMillion': 0,
#   'totalTests': 4715,
#   'testsPerOneMillion': 195},
#  {'country': 'Burkina Faso',
#   'cases': 565,
#   'todayCases': 0,
#   'deaths': 36,
#   'todayDeaths': 0,
#   'recovered': 321,
#   'active': 208,
#   'critical': 0,
#   'casesPerOneMillion': 27,
#   'deathsPerOneMillion': 2,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Albania',
#   'cases': 562,
#   'todayCases': 14,
#   'deaths': 26,
#   'todayDeaths': 0,
#   'recovered': 314,
#   'active': 222,
#   'critical': 5,
#   'casesPerOneMillion': 195,
#   'deathsPerOneMillion': 9,
#   'totalTests': 5542,
#   'testsPerOneMillion': 1926},
#  {'country': 'Kyrgyzstan',
#   'cases': 554,
#   'todayCases': 48,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 133,
#   'active': 416,
#   'critical': 5,
#   'casesPerOneMillion': 85,
#   'deathsPerOneMillion': 0,
#   'totalTests': 26147,
#   'testsPerOneMillion': 4008},
#  {'country': 'Nigeria',
#   'cases': 542,
#   'todayCases': 0,
#   'deaths': 19,
#   'todayDeaths': 0,
#   'recovered': 166,
#   'active': 357,
#   'critical': 2,
#   'casesPerOneMillion': 3,
#   'deathsPerOneMillion': 0,
#   'totalTests': 7153,
#   'testsPerOneMillion': 35},
#  {'country': 'Bolivia',
#   'cases': 520,
#   'todayCases': 27,
#   'deaths': 32,
#   'todayDeaths': 1,
#   'recovered': 31,
#   'active': 457,
#   'critical': 3,
#   'casesPerOneMillion': 45,
#   'deathsPerOneMillion': 3,
#   'totalTests': 3569,
#   'testsPerOneMillion': 306},
#  {'country': 'Guinea',
#   'cases': 518,
#   'todayCases': 0,
#   'deaths': 3,
#   'todayDeaths': 0,
#   'recovered': 65,
#   'active': 450,
#   'critical': 0,
#   'casesPerOneMillion': 39,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Uruguay',
#   'cases': 517,
#   'todayCases': 0,
#   'deaths': 9,
#   'todayDeaths': 0,
#   'recovered': 298,
#   'active': 210,
#   'critical': 14,
#   'casesPerOneMillion': 149,
#   'deathsPerOneMillion': 3,
#   'totalTests': 12478,
#   'testsPerOneMillion': 3592},
#  {'country': 'Channel Islands',
#   'cases': 484,
#   'todayCases': 0,
#   'deaths': 21,
#   'todayDeaths': 0,
#   'recovered': 73,
#   'active': 390,
#   'critical': 0,
#   'casesPerOneMillion': 2784,
#   'deathsPerOneMillion': 121,
#   'totalTests': 3320,
#   'testsPerOneMillion': 19095},
#  {'country': 'Honduras',
#   'cases': 472,
#   'todayCases': 15,
#   'deaths': 46,
#   'todayDeaths': 0,
#   'recovered': 15,
#   'active': 411,
#   'critical': 10,
#   'casesPerOneMillion': 48,
#   'deathsPerOneMillion': 5,
#   'totalTests': 2535,
#   'testsPerOneMillion': 256},
#  {'country': 'San Marino',
#   'cases': 461,
#   'todayCases': 6,
#   'deaths': 39,
#   'todayDeaths': 0,
#   'recovered': 60,
#   'active': 362,
#   'critical': 4,
#   'casesPerOneMillion': 13586,
#   'deathsPerOneMillion': 1149,
#   'totalTests': 1711,
#   'testsPerOneMillion': 50426},
#  {'country': 'Palestine',
#   'cases': 431,
#   'todayCases': 13,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 71,
#   'active': 358,
#   'critical': 0,
#   'casesPerOneMillion': 84,
#   'deathsPerOneMillion': 0,
#   'totalTests': 17329,
#   'testsPerOneMillion': 3397},
#  {'country': 'Malta',
#   'cases': 427,
#   'todayCases': 1,
#   'deaths': 3,
#   'todayDeaths': 0,
#   'recovered': 118,
#   'active': 306,
#   'critical': 2,
#   'casesPerOneMillion': 967,
#   'deathsPerOneMillion': 7,
#   'totalTests': 23253,
#   'testsPerOneMillion': 52663},
#  {'country': 'Taiwan',
#   'cases': 420,
#   'todayCases': 22,
#   'deaths': 6,
#   'todayDeaths': 0,
#   'recovered': 189,
#   'active': 225,
#   'critical': 0,
#   'casesPerOneMillion': 18,
#   'deathsPerOneMillion': 0,
#   'totalTests': 53005,
#   'testsPerOneMillion': 2226},
#  {'country': 'Jordan',
#   'cases': 413,
#   'todayCases': 0,
#   'deaths': 7,
#   'todayDeaths': 0,
#   'recovered': 269,
#   'active': 137,
#   'critical': 5,
#   'casesPerOneMillion': 40,
#   'deathsPerOneMillion': 0,
#   'totalTests': 20500,
#   'testsPerOneMillion': 2009},
#  {'country': 'Réunion',
#   'cases': 407,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 237,
#   'active': 170,
#   'critical': 4,
#   'casesPerOneMillion': 455,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Georgia',
#   'cases': 394,
#   'todayCases': 6,
#   'deaths': 4,
#   'todayDeaths': 0,
#   'recovered': 86,
#   'active': 304,
#   'critical': 6,
#   'casesPerOneMillion': 99,
#   'deathsPerOneMillion': 1,
#   'totalTests': 5027,
#   'testsPerOneMillion': 1260},
#  {'country': 'Senegal',
#   'cases': 350,
#   'todayCases': 0,
#   'deaths': 3,
#   'todayDeaths': 0,
#   'recovered': 211,
#   'active': 136,
#   'critical': 1,
#   'casesPerOneMillion': 21,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'DRC',
#   'cases': 327,
#   'todayCases': 20,
#   'deaths': 25,
#   'todayDeaths': 0,
#   'recovered': 26,
#   'active': 276,
#   'critical': 0,
#   'casesPerOneMillion': 4,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Mauritius',
#   'cases': 325,
#   'todayCases': 0,
#   'deaths': 9,
#   'todayDeaths': 0,
#   'recovered': 180,
#   'active': 136,
#   'critical': 3,
#   'casesPerOneMillion': 256,
#   'deathsPerOneMillion': 7,
#   'totalTests': 9755,
#   'testsPerOneMillion': 7670},
#  {'country': 'Montenegro',
#   'cases': 308,
#   'todayCases': 1,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 55,
#   'active': 248,
#   'critical': 7,
#   'casesPerOneMillion': 490,
#   'deathsPerOneMillion': 8,
#   'totalTests': 3874,
#   'testsPerOneMillion': 6168},
#  {'country': 'Isle of Man',
#   'cases': 298,
#   'todayCases': 1,
#   'deaths': 6,
#   'todayDeaths': 0,
#   'recovered': 192,
#   'active': 100,
#   'critical': 11,
#   'casesPerOneMillion': 3505,
#   'deathsPerOneMillion': 71,
#   'totalTests': 2414,
#   'testsPerOneMillion': 28389},
#  {'country': 'Sri Lanka',
#   'cases': 269,
#   'todayCases': 15,
#   'deaths': 7,
#   'todayDeaths': 0,
#   'recovered': 96,
#   'active': 166,
#   'critical': 1,
#   'casesPerOneMillion': 13,
#   'deathsPerOneMillion': 0,
#   'totalTests': 4768,
#   'testsPerOneMillion': 223},
#  {'country': 'Vietnam',
#   'cases': 268,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 203,
#   'active': 65,
#   'critical': 8,
#   'casesPerOneMillion': 3,
#   'deathsPerOneMillion': 0,
#   'totalTests': 206253,
#   'testsPerOneMillion': 2119},
#  {'country': 'Kenya',
#   'cases': 262,
#   'todayCases': 0,
#   'deaths': 12,
#   'todayDeaths': 0,
#   'recovered': 60,
#   'active': 190,
#   'critical': 2,
#   'casesPerOneMillion': 5,
#   'deathsPerOneMillion': 0,
#   'totalTests': 10784,
#   'testsPerOneMillion': 201},
#  {'country': 'Guatemala',
#   'cases': 257,
#   'todayCases': 22,
#   'deaths': 7,
#   'todayDeaths': 0,
#   'recovered': 21,
#   'active': 229,
#   'critical': 3,
#   'casesPerOneMillion': 14,
#   'deathsPerOneMillion': 0,
#   'totalTests': 7200,
#   'testsPerOneMillion': 402},
#  {'country': 'Mayotte',
#   'cases': 254,
#   'todayCases': 0,
#   'deaths': 4,
#   'todayDeaths': 0,
#   'recovered': 117,
#   'active': 133,
#   'critical': 6,
#   'casesPerOneMillion': 931,
#   'deathsPerOneMillion': 15,
#   'totalTests': 1800,
#   'testsPerOneMillion': 6598},
#  {'country': 'Venezuela',
#   'cases': 227,
#   'todayCases': 0,
#   'deaths': 9,
#   'todayDeaths': 0,
#   'recovered': 117,
#   'active': 101,
#   'critical': 4,
#   'casesPerOneMillion': 8,
#   'deathsPerOneMillion': 0,
#   'totalTests': 299714,
#   'testsPerOneMillion': 10540},
#  {'country': 'Mali',
#   'cases': 216,
#   'todayCases': 0,
#   'deaths': 13,
#   'todayDeaths': 0,
#   'recovered': 41,
#   'active': 162,
#   'critical': 0,
#   'casesPerOneMillion': 11,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Paraguay',
#   'cases': 206,
#   'todayCases': 4,
#   'deaths': 8,
#   'todayDeaths': 0,
#   'recovered': 41,
#   'active': 157,
#   'critical': 1,
#   'casesPerOneMillion': 29,
#   'deathsPerOneMillion': 1,
#   'totalTests': 4950,
#   'testsPerOneMillion': 694},
#  {'country': 'El Salvador',
#   'cases': 201,
#   'todayCases': 11,
#   'deaths': 7,
#   'todayDeaths': 0,
#   'recovered': 44,
#   'active': 150,
#   'critical': 1,
#   'casesPerOneMillion': 31,
#   'deathsPerOneMillion': 1,
#   'totalTests': 11160,
#   'testsPerOneMillion': 1721},
#  {'country': 'Faeroe Islands',
#   'cases': 185,
#   'todayCases': 1,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 176,
#   'active': 9,
#   'critical': 0,
#   'casesPerOneMillion': 3786,
#   'deathsPerOneMillion': 0,
#   'totalTests': 6021,
#   'testsPerOneMillion': 123222},
#  {'country': 'Jamaica',
#   'cases': 173,
#   'todayCases': 10,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 25,
#   'active': 143,
#   'critical': 0,
#   'casesPerOneMillion': 58,
#   'deathsPerOneMillion': 2,
#   'totalTests': 1605,
#   'testsPerOneMillion': 542},
#  {'country': 'Martinique',
#   'cases': 163,
#   'todayCases': 0,
#   'deaths': 12,
#   'todayDeaths': 0,
#   'recovered': 73,
#   'active': 78,
#   'critical': 11,
#   'casesPerOneMillion': 434,
#   'deathsPerOneMillion': 32,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Guadeloupe',
#   'cases': 148,
#   'todayCases': 0,
#   'deaths': 8,
#   'todayDeaths': 0,
#   'recovered': 73,
#   'active': 67,
#   'critical': 13,
#   'casesPerOneMillion': 370,
#   'deathsPerOneMillion': 20,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Tanzania',
#   'cases': 147,
#   'todayCases': 0,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 11,
#   'active': 131,
#   'critical': 4,
#   'casesPerOneMillion': 2,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Rwanda',
#   'cases': 144,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 69,
#   'active': 75,
#   'critical': 0,
#   'casesPerOneMillion': 11,
#   'deathsPerOneMillion': 0,
#   'totalTests': 6237,
#   'testsPerOneMillion': 482},
#  {'country': 'Congo',
#   'cases': 143,
#   'todayCases': 0,
#   'deaths': 6,
#   'todayDeaths': 0,
#   'recovered': 11,
#   'active': 126,
#   'critical': 0,
#   'casesPerOneMillion': 26,
#   'deathsPerOneMillion': 1,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Brunei',
#   'cases': 138,
#   'todayCases': 1,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 115,
#   'active': 22,
#   'critical': 2,
#   'casesPerOneMillion': 315,
#   'deathsPerOneMillion': 2,
#   'totalTests': 11472,
#   'testsPerOneMillion': 26223},
#  {'country': 'Somalia',
#   'cases': 135,
#   'todayCases': 0,
#   'deaths': 7,
#   'todayDeaths': 0,
#   'recovered': 2,
#   'active': 126,
#   'critical': 2,
#   'casesPerOneMillion': 8,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Gibraltar',
#   'cases': 132,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 111,
#   'active': 21,
#   'critical': 1,
#   'casesPerOneMillion': 3918,
#   'deathsPerOneMillion': 0,
#   'totalTests': 1859,
#   'testsPerOneMillion': 55178},
#  {'country': 'Cambodia',
#   'cases': 122,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 105,
#   'active': 17,
#   'critical': 1,
#   'casesPerOneMillion': 7,
#   'deathsPerOneMillion': 0,
#   'totalTests': 5768,
#   'testsPerOneMillion': 345},
#  {'country': 'Madagascar',
#   'cases': 120,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 35,
#   'active': 85,
#   'critical': 1,
#   'casesPerOneMillion': 4,
#   'deathsPerOneMillion': 0,
#   'totalTests': 2357,
#   'testsPerOneMillion': 85},
#  {'country': 'Trinidad and Tobago',
#   'cases': 114,
#   'todayCases': 0,
#   'deaths': 8,
#   'todayDeaths': 0,
#   'recovered': 21,
#   'active': 85,
#   'critical': 0,
#   'casesPerOneMillion': 81,
#   'deathsPerOneMillion': 6,
#   'totalTests': 1320,
#   'testsPerOneMillion': 943},
#  {'country': 'Ethiopia',
#   'cases': 108,
#   'todayCases': 3,
#   'deaths': 3,
#   'todayDeaths': 0,
#   'recovered': 16,
#   'active': 89,
#   'critical': 1,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 7557,
#   'testsPerOneMillion': 66},
#  {'country': 'Gabon',
#   'cases': 108,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 7,
#   'active': 100,
#   'critical': 0,
#   'casesPerOneMillion': 49,
#   'deathsPerOneMillion': 0,
#   'totalTests': 572,
#   'testsPerOneMillion': 257},
#  {'country': 'Myanmar',
#   'cases': 107,
#   'todayCases': 9,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 5,
#   'active': 97,
#   'critical': 0,
#   'casesPerOneMillion': 2,
#   'deathsPerOneMillion': 0,
#   'totalTests': 4152,
#   'testsPerOneMillion': 76},
#  {'country': 'Aruba',
#   'cases': 96,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 44,
#   'active': 50,
#   'critical': 4,
#   'casesPerOneMillion': 899,
#   'deathsPerOneMillion': 19,
#   'totalTests': 1358,
#   'testsPerOneMillion': 12719},
#  {'country': 'French Guiana',
#   'cases': 96,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 64,
#   'active': 32,
#   'critical': 2,
#   'casesPerOneMillion': 321,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Monaco',
#   'cases': 94,
#   'todayCases': 0,
#   'deaths': 3,
#   'todayDeaths': 0,
#   'recovered': 22,
#   'active': 69,
#   'critical': 3,
#   'casesPerOneMillion': 2395,
#   'deathsPerOneMillion': 76,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Bermuda',
#   'cases': 86,
#   'todayCases': 3,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 35,
#   'active': 46,
#   'critical': 10,
#   'casesPerOneMillion': 1381,
#   'deathsPerOneMillion': 80,
#   'totalTests': 638,
#   'testsPerOneMillion': 10244},
#  {'country': 'Togo',
#   'cases': 84,
#   'todayCases': 0,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 49,
#   'active': 30,
#   'critical': 0,
#   'casesPerOneMillion': 10,
#   'deathsPerOneMillion': 0,
#   'totalTests': 4191,
#   'testsPerOneMillion': 506},
#  {'country': 'Liechtenstein',
#   'cases': 79,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 55,
#   'active': 23,
#   'critical': 0,
#   'casesPerOneMillion': 2072,
#   'deathsPerOneMillion': 26,
#   'totalTests': 900,
#   'testsPerOneMillion': 23605},
#  {'country': 'Equatorial Guinea',
#   'cases': 79,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 4,
#   'active': 75,
#   'critical': 0,
#   'casesPerOneMillion': 56,
#   'deathsPerOneMillion': 0,
#   'totalTests': 854,
#   'testsPerOneMillion': 609},
#  {'country': 'Liberia',
#   'cases': 76,
#   'todayCases': 0,
#   'deaths': 7,
#   'todayDeaths': 0,
#   'recovered': 7,
#   'active': 62,
#   'critical': 0,
#   'casesPerOneMillion': 15,
#   'deathsPerOneMillion': 1,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Barbados',
#   'cases': 75,
#   'todayCases': 0,
#   'deaths': 5,
#   'todayDeaths': 0,
#   'recovered': 17,
#   'active': 53,
#   'critical': 4,
#   'casesPerOneMillion': 261,
#   'deathsPerOneMillion': 17,
#   'totalTests': 1000,
#   'testsPerOneMillion': 3480},
#  {'country': 'Sudan',
#   'cases': 66,
#   'todayCases': 0,
#   'deaths': 10,
#   'todayDeaths': 0,
#   'recovered': 6,
#   'active': 50,
#   'critical': 0,
#   'casesPerOneMillion': 2,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Sint Maarten',
#   'cases': 64,
#   'todayCases': 0,
#   'deaths': 9,
#   'todayDeaths': 0,
#   'recovered': 12,
#   'active': 43,
#   'critical': 6,
#   'casesPerOneMillion': 1493,
#   'deathsPerOneMillion': 210,
#   'totalTests': 163,
#   'testsPerOneMillion': 3802},
#  {'country': 'Guyana',
#   'cases': 63,
#   'todayCases': 0,
#   'deaths': 6,
#   'todayDeaths': 0,
#   'recovered': 9,
#   'active': 48,
#   'critical': 4,
#   'casesPerOneMillion': 80,
#   'deathsPerOneMillion': 8,
#   'totalTests': 283,
#   'testsPerOneMillion': 360},
#  {'country': 'Zambia',
#   'cases': 61,
#   'todayCases': 4,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 33,
#   'active': 26,
#   'critical': 1,
#   'casesPerOneMillion': 3,
#   'deathsPerOneMillion': 0,
#   'totalTests': 2191,
#   'testsPerOneMillion': 119},
#  {'country': 'Cabo Verde',
#   'cases': 61,
#   'todayCases': 3,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 1,
#   'active': 59,
#   'critical': 0,
#   'casesPerOneMillion': 110,
#   'deathsPerOneMillion': 2,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Cayman Islands',
#   'cases': 61,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 7,
#   'active': 53,
#   'critical': 3,
#   'casesPerOneMillion': 928,
#   'deathsPerOneMillion': 15,
#   'totalTests': 702,
#   'testsPerOneMillion': 10681},
#  {'country': 'Bahamas',
#   'cases': 55,
#   'todayCases': 0,
#   'deaths': 9,
#   'todayDeaths': 0,
#   'recovered': 10,
#   'active': 36,
#   'critical': 1,
#   'casesPerOneMillion': 140,
#   'deathsPerOneMillion': 23,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'French Polynesia',
#   'cases': 55,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 2,
#   'active': 53,
#   'critical': 1,
#   'casesPerOneMillion': 196,
#   'deathsPerOneMillion': 0,
#   'totalTests': 1302,
#   'testsPerOneMillion': 4635},
#  {'country': 'Uganda',
#   'cases': 55,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 28,
#   'active': 27,
#   'critical': 0,
#   'casesPerOneMillion': 1,
#   'deathsPerOneMillion': 0,
#   'totalTests': 11101,
#   'testsPerOneMillion': 243},
#  {'country': 'Maldives',
#   'cases': 51,
#   'todayCases': 16,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 16,
#   'active': 35,
#   'critical': 0,
#   'casesPerOneMillion': 94,
#   'deathsPerOneMillion': 0,
#   'totalTests': 3714,
#   'testsPerOneMillion': 6871},
#  {'country': 'Libya',
#   'cases': 49,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 11,
#   'active': 37,
#   'critical': 0,
#   'casesPerOneMillion': 7,
#   'deathsPerOneMillion': 0,
#   'totalTests': 707,
#   'testsPerOneMillion': 103},
#  {'country': 'Guinea-Bissau',
#   'cases': 46,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 46,
#   'critical': 0,
#   'casesPerOneMillion': 23,
#   'deathsPerOneMillion': 0,
#   'totalTests': 1500,
#   'testsPerOneMillion': 762},
#  {'country': 'Macao',
#   'cases': 45,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 16,
#   'active': 29,
#   'critical': 1,
#   'casesPerOneMillion': 69,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Haiti',
#   'cases': 44,
#   'todayCases': 0,
#   'deaths': 3,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 41,
#   'critical': 0,
#   'casesPerOneMillion': 4,
#   'deathsPerOneMillion': 0,
#   'totalTests': 498,
#   'testsPerOneMillion': 44},
#  {'country': 'Eritrea',
#   'cases': 39,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 3,
#   'active': 36,
#   'critical': 0,
#   'casesPerOneMillion': 11,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Mozambique',
#   'cases': 39,
#   'todayCases': 4,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 8,
#   'active': 31,
#   'critical': 0,
#   'casesPerOneMillion': 1,
#   'deathsPerOneMillion': 0,
#   'totalTests': 1037,
#   'testsPerOneMillion': 33},
#  {'country': 'Syria',
#   'cases': 38,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 5,
#   'active': 31,
#   'critical': 0,
#   'casesPerOneMillion': 2,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Saint Martin',
#   'cases': 37,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 19,
#   'active': 16,
#   'critical': 5,
#   'casesPerOneMillion': 957,
#   'deathsPerOneMillion': 52,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Benin',
#   'cases': 35,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 18,
#   'active': 16,
#   'critical': 0,
#   'casesPerOneMillion': 3,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Chad',
#   'cases': 33,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 8,
#   'active': 25,
#   'critical': 0,
#   'casesPerOneMillion': 2,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Mongolia',
#   'cases': 32,
#   'todayCases': 1,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 7,
#   'active': 25,
#   'critical': 0,
#   'casesPerOneMillion': 10,
#   'deathsPerOneMillion': 0,
#   'totalTests': 1554,
#   'testsPerOneMillion': 474},
#  {'country': 'Nepal',
#   'cases': 31,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 4,
#   'active': 27,
#   'critical': 0,
#   'casesPerOneMillion': 1,
#   'deathsPerOneMillion': 0,
#   'totalTests': 27471,
#   'testsPerOneMillion': 943},
#  {'country': 'Sierra Leone',
#   'cases': 30,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 30,
#   'critical': 0,
#   'casesPerOneMillion': 4,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Zimbabwe',
#   'cases': 25,
#   'todayCases': 0,
#   'deaths': 3,
#   'todayDeaths': 0,
#   'recovered': 2,
#   'active': 20,
#   'critical': 0,
#   'casesPerOneMillion': 2,
#   'deathsPerOneMillion': 0,
#   'totalTests': 2626,
#   'testsPerOneMillion': 177},
#  {'country': 'Angola',
#   'cases': 24,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 6,
#   'active': 16,
#   'critical': 0,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Antigua and Barbuda',
#   'cases': 23,
#   'todayCases': 0,
#   'deaths': 3,
#   'todayDeaths': 0,
#   'recovered': 3,
#   'active': 17,
#   'critical': 1,
#   'casesPerOneMillion': 235,
#   'deathsPerOneMillion': 31,
#   'totalTests': 73,
#   'testsPerOneMillion': 745},
#  {'country': 'Eswatini',
#   'cases': 22,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 8,
#   'active': 13,
#   'critical': 0,
#   'casesPerOneMillion': 19,
#   'deathsPerOneMillion': 0,
#   'totalTests': 714,
#   'testsPerOneMillion': 615},
#  {'country': 'Botswana',
#   'cases': 20,
#   'todayCases': 5,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 19,
#   'critical': 0,
#   'casesPerOneMillion': 9,
#   'deathsPerOneMillion': 0,
#   'totalTests': 3602,
#   'testsPerOneMillion': 1532},
#  {'country': 'Laos',
#   'cases': 19,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 2,
#   'active': 17,
#   'critical': 0,
#   'casesPerOneMillion': 3,
#   'deathsPerOneMillion': 0,
#   'totalTests': 1333,
#   'testsPerOneMillion': 183},
#  {'country': 'Timor-Leste',
#   'cases': 19,
#   'todayCases': 1,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 1,
#   'active': 18,
#   'critical': 0,
#   'casesPerOneMillion': 14,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Belize',
#   'cases': 18,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 16,
#   'critical': 1,
#   'casesPerOneMillion': 45,
#   'deathsPerOneMillion': 5,
#   'totalTests': 651,
#   'testsPerOneMillion': 1637},
#  {'country': 'New Caledonia',
#   'cases': 18,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 15,
#   'active': 3,
#   'critical': 1,
#   'casesPerOneMillion': 63,
#   'deathsPerOneMillion': 0,
#   'totalTests': 3399,
#   'testsPerOneMillion': 11906},
#  {'country': 'Malawi',
#   'cases': 17,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 3,
#   'active': 12,
#   'critical': 1,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 417,
#   'testsPerOneMillion': 22},
#  {'country': 'Fiji',
#   'cases': 17,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 17,
#   'critical': 0,
#   'casesPerOneMillion': 19,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Dominica',
#   'cases': 16,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 8,
#   'active': 8,
#   'critical': 0,
#   'casesPerOneMillion': 222,
#   'deathsPerOneMillion': 0,
#   'totalTests': 345,
#   'testsPerOneMillion': 4793},
#  {'country': 'Namibia',
#   'cases': 16,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 6,
#   'active': 10,
#   'critical': 0,
#   'casesPerOneMillion': 6,
#   'deathsPerOneMillion': 0,
#   'totalTests': 524,
#   'testsPerOneMillion': 206},
#  {'country': 'Saint Lucia',
#   'cases': 15,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 11,
#   'active': 4,
#   'critical': 0,
#   'casesPerOneMillion': 82,
#   'deathsPerOneMillion': 0,
#   'totalTests': 344,
#   'testsPerOneMillion': 1873},
#  {'country': 'Curaçao',
#   'cases': 14,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 11,
#   'active': 2,
#   'critical': 0,
#   'casesPerOneMillion': 85,
#   'deathsPerOneMillion': 6,
#   'totalTests': 286,
#   'testsPerOneMillion': 1743},
#  {'country': 'Grenada',
#   'cases': 14,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 6,
#   'active': 8,
#   'critical': 4,
#   'casesPerOneMillion': 124,
#   'deathsPerOneMillion': 0,
#   'totalTests': 92,
#   'testsPerOneMillion': 818},
#  {'country': 'Saint Kitts and Nevis',
#   'cases': 14,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 14,
#   'critical': 0,
#   'casesPerOneMillion': 263,
#   'deathsPerOneMillion': 0,
#   'totalTests': 234,
#   'testsPerOneMillion': 4399},
#  {'country': 'CAR',
#   'cases': 12,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 4,
#   'active': 8,
#   'critical': 0,
#   'casesPerOneMillion': 2,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'St. Vincent Grenadines',
#   'cases': 12,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 1,
#   'active': 11,
#   'critical': 0,
#   'casesPerOneMillion': 108,
#   'deathsPerOneMillion': 0,
#   'totalTests': 87,
#   'testsPerOneMillion': 784},
#  {'country': 'Turks and Caicos',
#   'cases': 11,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 10,
#   'critical': 0,
#   'casesPerOneMillion': 284,
#   'deathsPerOneMillion': 26,
#   'totalTests': 83,
#   'testsPerOneMillion': 2144},
#  {'country': 'Falkland Islands',
#   'cases': 11,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 3,
#   'active': 8,
#   'critical': 0,
#   'casesPerOneMillion': 3161,
#   'deathsPerOneMillion': 0,
#   'totalTests': 319,
#   'testsPerOneMillion': 91667},
#  {'country': 'Greenland',
#   'cases': 11,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 11,
#   'active': 0,
#   'critical': 0,
#   'casesPerOneMillion': 194,
#   'deathsPerOneMillion': 0,
#   'totalTests': 1043,
#   'testsPerOneMillion': 18372},
#  {'country': 'Montserrat',
#   'cases': 11,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 2,
#   'active': 9,
#   'critical': 1,
#   'casesPerOneMillion': 2204,
#   'deathsPerOneMillion': 0,
#   'totalTests': 36,
#   'testsPerOneMillion': 7212},
#  {'country': 'Seychelles',
#   'cases': 11,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 5,
#   'active': 6,
#   'critical': 0,
#   'casesPerOneMillion': 112,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Suriname',
#   'cases': 10,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 6,
#   'active': 3,
#   'critical': 0,
#   'casesPerOneMillion': 17,
#   'deathsPerOneMillion': 2,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'MS Zaandam',
#   'cases': 9,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 7,
#   'critical': 0,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Nicaragua',
#   'cases': 9,
#   'todayCases': 0,
#   'deaths': 2,
#   'todayDeaths': 0,
#   'recovered': 6,
#   'active': 1,
#   'critical': 0,
#   'casesPerOneMillion': 1,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Gambia',
#   'cases': 9,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 2,
#   'active': 6,
#   'critical': 0,
#   'casesPerOneMillion': 4,
#   'deathsPerOneMillion': 0,
#   'totalTests': 316,
#   'testsPerOneMillion': 131},
#  {'country': 'Vatican City',
#   'cases': 8,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 2,
#   'active': 6,
#   'critical': 0,
#   'casesPerOneMillion': 9988,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Mauritania',
#   'cases': 7,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 6,
#   'active': 0,
#   'critical': 0,
#   'casesPerOneMillion': 2,
#   'deathsPerOneMillion': 0,
#   'totalTests': 913,
#   'testsPerOneMillion': 196},
#  {'country': 'Papua New Guinea',
#   'cases': 7,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 7,
#   'critical': 0,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 167,
#   'testsPerOneMillion': 19},
#  {'country': 'St. Barth',
#   'cases': 6,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 5,
#   'active': 1,
#   'critical': 0,
#   'casesPerOneMillion': 607,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Western Sahara',
#   'cases': 6,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 6,
#   'critical': 0,
#   'casesPerOneMillion': 10,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Burundi',
#   'cases': 5,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 4,
#   'critical': 0,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 80,
#   'testsPerOneMillion': 7},
#  {'country': 'Bhutan',
#   'cases': 5,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 2,
#   'active': 3,
#   'critical': 0,
#   'casesPerOneMillion': 6,
#   'deathsPerOneMillion': 0,
#   'totalTests': 8107,
#   'testsPerOneMillion': 10507},
#  {'country': 'Caribbean Netherlands',
#   'cases': 5,
#   'todayCases': 2,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 5,
#   'critical': 0,
#   'casesPerOneMillion': 191,
#   'deathsPerOneMillion': 0,
#   'totalTests': 110,
#   'testsPerOneMillion': 4195},
#  {'country': 'British Virgin Islands',
#   'cases': 4,
#   'todayCases': 0,
#   'deaths': 1,
#   'todayDeaths': 1,
#   'recovered': 2,
#   'active': 1,
#   'critical': 0,
#   'casesPerOneMillion': 132,
#   'deathsPerOneMillion': 33,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Sao Tome and Principe',
#   'cases': 4,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 4,
#   'critical': 0,
#   'casesPerOneMillion': 18,
#   'deathsPerOneMillion': 0,
#   'totalTests': 19,
#   'testsPerOneMillion': 87},
#  {'country': 'South Sudan',
#   'cases': 4,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 4,
#   'critical': 0,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Anguilla',
#   'cases': 3,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 1,
#   'active': 2,
#   'critical': 0,
#   'casesPerOneMillion': 200,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Saint Pierre Miquelon',
#   'cases': 1,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 1,
#   'critical': 0,
#   'casesPerOneMillion': 173,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Yemen',
#   'cases': 1,
#   'todayCases': 0,
#   'deaths': 0,
#   'todayDeaths': 0,
#   'recovered': 0,
#   'active': 1,
#   'critical': 0,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'China',
#   'cases': 82735,
#   'todayCases': 16,
#   'deaths': 4632,
#   'todayDeaths': 0,
#   'recovered': 77062,
#   'active': 1041,
#   'critical': 85,
#   'casesPerOneMillion': 57,
#   'deathsPerOneMillion': 3,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Total:',
#   'cases': 792769,
#   'todayCases': 1363,
#   'deaths': 41670,
#   'todayDeaths': 133,
#   'recovered': 83535,
#   'active': 667564,
#   'critical': 14660,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Total:',
#   'cases': 1079650,
#   'todayCases': 19614,
#   'deaths': 100794,
#   'todayDeaths': 1516,
#   'recovered': 305791,
#   'active': 673065,
#   'critical': 25711,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Total:',
#   'cases': 376860,
#   'todayCases': 6076,
#   'deaths': 14593,
#   'todayDeaths': 192,
#   'recovered': 178315,
#   'active': 183952,
#   'critical': 6357,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Total:',
#   'cases': 78207,
#   'todayCases': 234,
#   'deaths': 3665,
#   'todayDeaths': 12,
#   'recovered': 27698,
#   'active': 46844,
#   'critical': 7532,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Total:',
#   'cases': 8134,
#   'todayCases': 29,
#   'deaths': 82,
#   'todayDeaths': 1,
#   'recovered': 5159,
#   'active': 2893,
#   'critical': 68,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Total:',
#   'cases': 21915,
#   'todayCases': 174,
#   'deaths': 1083,
#   'todayDeaths': 1,
#   'recovered': 5488,
#   'active': 15344,
#   'critical': 195,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0},
#  {'country': 'Total:',
#   'cases': 721,
#   'todayCases': 0,
#   'deaths': 15,
#   'todayDeaths': 0,
#   'recovered': 644,
#   'active': 62,
#   'critical': 7,
#   'casesPerOneMillion': 0,
#   'deathsPerOneMillion': 0,
#   'totalTests': 0,
#   'testsPerOneMillion': 0}]

# %%
Countries_df = json_normalize(response.json(), errors='ignore')
Countries_df
# Out:
#            country    cases  todayCases  deaths  todayDeaths  recovered  \
# 0    North America   792769        1363   41670          133    83535.0
# 1           Europe  1079650       19614  100794         1516   305791.0
# 2             Asia   376860        6076   14593          192   178315.0
# 3    South America    78207         234    3665           12    27698.0
# 4          Oceania     8134          29      82            1     5159.0
# ..             ...      ...         ...     ...          ...        ...
# 222         Total:   376860        6076   14593          192   178315.0
# 223         Total:    78207         234    3665           12    27698.0
# 224         Total:     8134          29      82            1     5159.0
# 225         Total:    21915         174    1083            1     5488.0
# 226         Total:      721           0      15            0      644.0
#
#      active  critical  casesPerOneMillion  deathsPerOneMillion  totalTests  \
# 0    667564     14660                   0                    0           0
# 1    673065     25711                   0                    0           0
# 2    183952      6357                   0                    0           0
# 3     46844      7532                   0                    0           0
# 4      2893        68                   0                    0           0
# ..      ...       ...                 ...                  ...         ...
# 222  183952      6357                   0                    0           0
# 223   46844      7532                   0                    0           0
# 224    2893        68                   0                    0           0
# 225   15344       195                   0                    0           0
# 226      62         7                   0                    0           0
#
#      testsPerOneMillion
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 222                   0
# 223                   0
# 224                   0
# 225                   0
# 226                   0
#
# [227 rows x 12 columns]

# %%
Countries_df.iloc[:,[0,1,2,3,4,5,6,7]]
# Out:
#            country    cases  todayCases  deaths  todayDeaths  recovered  \
# 0    North America   792769        1363   41670          133    83535.0
# 1           Europe  1079650       19614  100794         1516   305791.0
# 2             Asia   376860        6076   14593          192   178315.0
# 3    South America    78207         234    3665           12    27698.0
# 4          Oceania     8134          29      82            1     5159.0
# ..             ...      ...         ...     ...          ...        ...
# 222         Total:   376860        6076   14593          192   178315.0
# 223         Total:    78207         234    3665           12    27698.0
# 224         Total:     8134          29      82            1     5159.0
# 225         Total:    21915         174    1083            1     5488.0
# 226         Total:      721           0      15            0      644.0
#
#      active  critical
# 0    667564     14660
# 1    673065     25711
# 2    183952      6357
# 3     46844      7532
# 4      2893        68
# ..      ...       ...
# 222  183952      6357
# 223   46844      7532
# 224    2893        68
# 225   15344       195
# 226      62         7
#
# [227 rows x 8 columns]

# %%
response = requests.get(url3)
response.json()
# Out:
# [{'state': 'AK',
#   'positive': 314,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 9341,
#   'pending': None,
#   'hospitalizedCurrently': 39,
#   'hospitalizedCumulative': 36,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 147,
#   'lastUpdateEt': '4/18 14:15',
#   'checkTimeEt': '4/18 15:09',
#   'death': 9,
#   'hospitalized': 36,
#   'total': 9655,
#   'totalTestResults': 9655,
#   'posNeg': 9655,
#   'fips': '02',
#   'dateModified': '2020-04-18T18:15:00Z',
#   'dateChecked': '2020-04-18T19:09:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '363f0fd82439b801b085e6b3371f7655b02592b8'},
#  {'state': 'AL',
#   'positive': 4723,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 0,
#   'commercialScore': 1,
#   'grade': 'B',
#   'score': 3,
#   'negative': 37883,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 620,
#   'inIcuCurrently': None,
#   'inIcuCumulative': 247,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': 148,
#   'recovered': None,
#   'lastUpdateEt': '4/18 00:00',
#   'checkTimeEt': '4/18 22:13',
#   'death': 147,
#   'hospitalized': 620,
#   'total': 42606,
#   'totalTestResults': 42606,
#   'posNeg': 42606,
#   'fips': '01',
#   'dateModified': '2020-04-18T04:00:00Z',
#   'dateChecked': '2020-04-19T02:13:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'd9a1b4e0f0d5c2ce4470c5e29fe02b1df29639ff'},
#  {'state': 'AR',
#   'positive': 1777,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 22428,
#   'pending': None,
#   'hospitalizedCurrently': 93,
#   'hospitalizedCumulative': 291,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 23,
#   'onVentilatorCumulative': 57,
#   'recovered': 719,
#   'lastUpdateEt': '4/18 15:41',
#   'checkTimeEt': '4/18 23:24',
#   'death': 38,
#   'hospitalized': 291,
#   'total': 24205,
#   'totalTestResults': 24205,
#   'posNeg': 24205,
#   'fips': '05',
#   'dateModified': '2020-04-18T19:41:00Z',
#   'dateChecked': '2020-04-19T03:24:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'a2a34e8451646d52aec40d914139d14c4e2ea4e3'},
#  {'state': 'AZ',
#   'positive': 4719,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 0,
#   'commercialScore': 1,
#   'grade': 'B',
#   'score': 3,
#   'negative': 46326,
#   'pending': None,
#   'hospitalizedCurrently': 566,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 285,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 178,
#   'onVentilatorCumulative': None,
#   'recovered': 539,
#   'lastUpdateEt': '4/18 00:00',
#   'checkTimeEt': '4/18 15:25',
#   'death': 177,
#   'hospitalized': None,
#   'total': 51045,
#   'totalTestResults': 51045,
#   'posNeg': 51045,
#   'fips': '04',
#   'dateModified': '2020-04-18T04:00:00Z',
#   'dateChecked': '2020-04-18T19:25:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '6f5351e769c581777aba8523f997e8eed562fbea'},
#  {'state': 'CA',
#   'positive': 28963,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 0,
#   'commercialScore': 1,
#   'grade': 'B',
#   'score': 3,
#   'negative': 230703,
#   'pending': 7200,
#   'hospitalizedCurrently': 4936,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1490,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/17 00:00',
#   'checkTimeEt': '4/18 18:52',
#   'death': 1072,
#   'hospitalized': None,
#   'total': 266866,
#   'totalTestResults': 259666,
#   'posNeg': 259666,
#   'fips': '06',
#   'dateModified': '2020-04-17T04:00:00Z',
#   'dateChecked': '2020-04-18T22:52:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'a185c582ec6d052ead9b88a7e5a25c27cad4d89d'},
#  {'state': 'CO',
#   'positive': 9433,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 35173,
#   'pending': None,
#   'hospitalizedCurrently': 843,
#   'hospitalizedCumulative': 1797,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 00:00',
#   'checkTimeEt': '4/18 22:26',
#   'death': 411,
#   'hospitalized': 1797,
#   'total': 44606,
#   'totalTestResults': 44606,
#   'posNeg': 44606,
#   'fips': '08',
#   'dateModified': '2020-04-18T04:00:00Z',
#   'dateChecked': '2020-04-19T02:26:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '9c71664393c1015491ec091ee9889072dde7f46e'},
#  {'state': 'CT',
#   'positive': 17550,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 40663,
#   'pending': None,
#   'hospitalizedCurrently': 1938,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 00:00',
#   'checkTimeEt': '4/18 22:42',
#   'death': 1086,
#   'hospitalized': None,
#   'total': 58213,
#   'totalTestResults': 58213,
#   'posNeg': 58213,
#   'fips': '09',
#   'dateModified': '2020-04-18T04:00:00Z',
#   'dateChecked': '2020-04-19T02:42:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'eb95a8804158fd9b1b8bc83c216f4d9454eededb'},
#  {'state': 'DC',
#   'positive': 2666,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 10602,
#   'pending': None,
#   'hospitalizedCurrently': 313,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 105,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 79,
#   'onVentilatorCumulative': None,
#   'recovered': 608,
#   'lastUpdateEt': '4/17 00:00',
#   'checkTimeEt': '4/18 15:29',
#   'death': 91,
#   'hospitalized': None,
#   'total': 13268,
#   'totalTestResults': 13268,
#   'posNeg': 13268,
#   'fips': '11',
#   'dateModified': '2020-04-17T04:00:00Z',
#   'dateChecked': '2020-04-18T19:29:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '9836e127cfb29ac8dbd92f24dc653538b6bfdde8'},
#  {'state': 'DE',
#   'positive': 2538,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 12256,
#   'pending': None,
#   'hospitalizedCurrently': 249,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 466,
#   'lastUpdateEt': '4/18 17:00',
#   'checkTimeEt': '4/18 22:44',
#   'death': 67,
#   'hospitalized': None,
#   'total': 14794,
#   'totalTestResults': 14794,
#   'posNeg': 14794,
#   'fips': '10',
#   'dateModified': '2020-04-18T21:00:00Z',
#   'dateChecked': '2020-04-19T02:44:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'f04002498da1e046967738d1cc25f933c7348553'},
#  {'state': 'FL',
#   'positive': 25492,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 225862,
#   'pending': 1214,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 3908,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 16:24',
#   'checkTimeEt': '4/18 22:46',
#   'death': 765,
#   'hospitalized': 3908,
#   'total': 252568,
#   'totalTestResults': 251354,
#   'posNeg': 251354,
#   'fips': '12',
#   'dateModified': '2020-04-18T20:24:00Z',
#   'dateChecked': '2020-04-19T02:46:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '346f0224af1eb35378b5d5775d7945de11cb4c95'},
#  {'state': 'GA',
#   'positive': 17841,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 56539,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 3447,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 18:28',
#   'checkTimeEt': '4/18 22:54',
#   'death': 677,
#   'hospitalized': 3447,
#   'total': 74380,
#   'totalTestResults': 74380,
#   'posNeg': 74380,
#   'fips': '13',
#   'dateModified': '2020-04-18T22:28:00Z',
#   'dateChecked': '2020-04-19T02:54:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '58e7ffc117a671b25b2d8596ce8eb55b6d2b510f'},
#  {'state': 'HI',
#   'positive': 564,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 22896,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 51,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 410,
#   'lastUpdateEt': '4/18 18:30',
#   'checkTimeEt': '4/18 23:38',
#   'death': 9,
#   'hospitalized': 51,
#   'total': 23460,
#   'totalTestResults': 23460,
#   'posNeg': 23460,
#   'fips': '15',
#   'dateModified': '2020-04-18T22:30:00Z',
#   'dateChecked': '2020-04-19T03:38:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '419d1c73d2e7925904611eb5217dd0b9fb70f4e7'},
#  {'state': 'IA',
#   'positive': 2513,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 20434,
#   'pending': None,
#   'hospitalizedCurrently': 193,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 84,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 51,
#   'onVentilatorCumulative': None,
#   'recovered': 1095,
#   'lastUpdateEt': '4/17 12:00',
#   'checkTimeEt': '4/18 23:18',
#   'death': 74,
#   'hospitalized': None,
#   'total': 22947,
#   'totalTestResults': 22947,
#   'posNeg': 22947,
#   'fips': '19',
#   'dateModified': '2020-04-17T16:00:00Z',
#   'dateChecked': '2020-04-19T03:18:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '5d758eaa20327eb15ef331808f71bf4b9b39532e'},
#  {'state': 'ID',
#   'positive': 1668,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 15201,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 151,
#   'inIcuCurrently': None,
#   'inIcuCumulative': 53,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 520,
#   'lastUpdateEt': '4/18 19:00',
#   'checkTimeEt': '4/18 23:13',
#   'death': 44,
#   'hospitalized': 151,
#   'total': 16869,
#   'totalTestResults': 16869,
#   'posNeg': 16869,
#   'fips': '16',
#   'dateModified': '2020-04-18T23:00:00Z',
#   'dateChecked': '2020-04-19T03:13:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '0d1d9be44fb4aa32d6237c8e5055f9b4d20d1d6c'},
#  {'state': 'IL',
#   'positive': 29160,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 108244,
#   'pending': None,
#   'hospitalizedCurrently': 4340,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1192,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 740,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 00:00',
#   'checkTimeEt': '4/18 16:05',
#   'death': 1259,
#   'hospitalized': None,
#   'total': 137404,
#   'totalTestResults': 137404,
#   'posNeg': 137404,
#   'fips': '17',
#   'dateModified': '2020-04-18T04:00:00Z',
#   'dateChecked': '2020-04-18T20:05:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '09ee6ac31c1657d678fca17cac336d47d7b2d075'},
#  {'state': 'IN',
#   'positive': 10641,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 0,
#   'grade': 'B',
#   'score': 3,
#   'negative': 46232,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 663,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 360,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/17 23:59',
#   'checkTimeEt': '4/18 15:54',
#   'death': 545,
#   'hospitalized': None,
#   'total': 56873,
#   'totalTestResults': 56873,
#   'posNeg': 56873,
#   'fips': '18',
#   'dateModified': '2020-04-18T03:59:00Z',
#   'dateChecked': '2020-04-18T19:54:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'f8aec48409289ca99b70a4f7ef1d9d669a7e01b8'},
#  {'state': 'KS',
#   'positive': 1790,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 0,
#   'grade': 'B',
#   'score': 3,
#   'negative': 15886,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 383,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 12:00',
#   'checkTimeEt': '4/18 15:55',
#   'death': 86,
#   'hospitalized': 383,
#   'total': 17676,
#   'totalTestResults': 17676,
#   'posNeg': 17676,
#   'fips': '20',
#   'dateModified': '2020-04-18T16:00:00Z',
#   'dateChecked': '2020-04-18T19:55:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '5e2b1cbbd2905df3a6e35c1648312d4ac6a0d333'},
#  {'state': 'KY',
#   'positive': 2707,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 29518,
#   'pending': None,
#   'hospitalizedCurrently': 274,
#   'hospitalizedCumulative': 1059,
#   'inIcuCurrently': 155,
#   'inIcuCumulative': 534,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 1174,
#   'lastUpdateEt': '4/18 17:00',
#   'checkTimeEt': '4/18 22:45',
#   'death': 144,
#   'hospitalized': 1059,
#   'total': 32225,
#   'totalTestResults': 32225,
#   'posNeg': 32225,
#   'fips': '21',
#   'dateModified': '2020-04-18T21:00:00Z',
#   'dateChecked': '2020-04-19T02:45:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '8c3e8b53fae63be4828cf699ed1a09bada075fca'},
#  {'state': 'LA',
#   'positive': 23580,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 114419,
#   'pending': None,
#   'hospitalizedCurrently': 1761,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 347,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 13:00',
#   'checkTimeEt': '4/18 15:20',
#   'death': 1267,
#   'hospitalized': None,
#   'total': 137999,
#   'totalTestResults': 137999,
#   'posNeg': 137999,
#   'fips': '22',
#   'dateModified': '2020-04-18T17:00:00Z',
#   'dateChecked': '2020-04-18T19:20:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '50e8242e1e7cd1c3d7bc2505e4b63ef969705dce'},
#  {'state': 'MA',
#   'positive': 36372,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 0,
#   'commercialScore': 1,
#   'grade': 'B',
#   'score': 3,
#   'negative': 120434,
#   'pending': None,
#   'hospitalizedCurrently': 3729,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 987,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 10:00',
#   'checkTimeEt': '4/18 23:13',
#   'death': 1560,
#   'hospitalized': None,
#   'total': 156806,
#   'totalTestResults': 156806,
#   'posNeg': 156806,
#   'fips': '25',
#   'dateModified': '2020-04-18T14:00:00Z',
#   'dateChecked': '2020-04-19T03:13:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'e990b1957b32867af7948c348e147387448813b6'},
#  {'state': 'MD',
#   'positive': 12308,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 53062,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 2757,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 771,
#   'lastUpdateEt': '4/18 10:00',
#   'checkTimeEt': '4/18 15:41',
#   'death': 463,
#   'hospitalized': 2757,
#   'total': 65370,
#   'totalTestResults': 65370,
#   'posNeg': 65370,
#   'fips': '24',
#   'dateModified': '2020-04-18T14:00:00Z',
#   'dateChecked': '2020-04-18T19:41:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '3a0b174064e41d533defe0fd755eb87ef21ef8d6'},
#  {'state': 'ME',
#   'positive': 847,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 14076,
#   'pending': None,
#   'hospitalizedCurrently': 49,
#   'hospitalizedCumulative': 136,
#   'inIcuCurrently': 20,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 12,
#   'onVentilatorCumulative': None,
#   'recovered': 382,
#   'lastUpdateEt': '4/18 15:00',
#   'checkTimeEt': '4/18 16:05',
#   'death': 32,
#   'hospitalized': 136,
#   'total': 14923,
#   'totalTestResults': 14923,
#   'posNeg': 14923,
#   'fips': '23',
#   'dateModified': '2020-04-18T19:00:00Z',
#   'dateChecked': '2020-04-18T20:05:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'e441a363c8ff01cce71271a910319eecd7cc3cec'},
#  {'state': 'MI',
#   'positive': 30791,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 0,
#   'commercialScore': 1,
#   'grade': 'B',
#   'score': 3,
#   'negative': 73233,
#   'pending': None,
#   'hospitalizedCurrently': 3403,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1344,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 1115,
#   'onVentilatorCumulative': None,
#   'recovered': 3237,
#   'lastUpdateEt': '4/18 11:00',
#   'checkTimeEt': '4/18 23:49',
#   'death': 2308,
#   'hospitalized': None,
#   'total': 104024,
#   'totalTestResults': 104024,
#   'posNeg': 104024,
#   'fips': '26',
#   'dateModified': '2020-04-18T15:00:00Z',
#   'dateChecked': '2020-04-19T03:49:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '05d84522edfbd01f4dc3b5eb56ad90d10fb41973'},
#  {'state': 'MN',
#   'positive': 2213,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 42055,
#   'pending': None,
#   'hospitalizedCurrently': 239,
#   'hospitalizedCumulative': 561,
#   'inIcuCurrently': 111,
#   'inIcuCumulative': 215,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 1118,
#   'lastUpdateEt': '4/17 17:00',
#   'checkTimeEt': '4/18 15:53',
#   'death': 121,
#   'hospitalized': 561,
#   'total': 44268,
#   'totalTestResults': 44268,
#   'posNeg': 44268,
#   'fips': '27',
#   'dateModified': '2020-04-17T21:00:00Z',
#   'dateChecked': '2020-04-18T19:53:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'b4745a2b1feb726deb4eae44a12199ac5ece84be'},
#  {'state': 'MO',
#   'positive': 5517,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 48242,
#   'pending': None,
#   'hospitalizedCurrently': 875,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 15:00',
#   'checkTimeEt': '4/18 15:45',
#   'death': 175,
#   'hospitalized': None,
#   'total': 53759,
#   'totalTestResults': 53759,
#   'posNeg': 53759,
#   'fips': '29',
#   'dateModified': '2020-04-18T19:00:00Z',
#   'dateChecked': '2020-04-18T19:45:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'f5194aab86d3029664dbea985288de14c30b7d89'},
#  {'state': 'MS',
#   'positive': 3974,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 34791,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 782,
#   'inIcuCurrently': 154,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 99,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/17 19:00',
#   'checkTimeEt': '4/18 23:37',
#   'death': 152,
#   'hospitalized': 782,
#   'total': 38765,
#   'totalTestResults': 38765,
#   'posNeg': 38765,
#   'fips': '28',
#   'dateModified': '2020-04-17T23:00:00Z',
#   'dateChecked': '2020-04-19T03:37:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '44f219854c697b0a6c331790c81b551c0ddfc9c0'},
#  {'state': 'MT',
#   'positive': 426,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 10143,
#   'pending': None,
#   'hospitalizedCurrently': 17,
#   'hospitalizedCumulative': 55,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 234,
#   'lastUpdateEt': '4/18 10:18',
#   'checkTimeEt': '4/18 15:34',
#   'death': 10,
#   'hospitalized': 55,
#   'total': 10569,
#   'totalTestResults': 10569,
#   'posNeg': 10569,
#   'fips': '30',
#   'dateModified': '2020-04-18T14:18:00Z',
#   'dateChecked': '2020-04-18T19:34:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'f5b6442dcdb019acb044863abb3995f60027b805'},
#  {'state': 'NC',
#   'positive': 6140,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 70071,
#   'pending': None,
#   'hospitalizedCurrently': 388,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 11:00',
#   'checkTimeEt': '4/18 14:56',
#   'death': 164,
#   'hospitalized': None,
#   'total': 76211,
#   'totalTestResults': 76211,
#   'posNeg': 76211,
#   'fips': '37',
#   'dateModified': '2020-04-18T15:00:00Z',
#   'dateChecked': '2020-04-18T18:56:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '232e1d026f04f30e61ae91a1c8b7079fe0186a58'},
#  {'state': 'ND',
#   'positive': 528,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 0,
#   'grade': 'B',
#   'score': 3,
#   'negative': 12435,
#   'pending': None,
#   'hospitalizedCurrently': 13,
#   'hospitalizedCumulative': 47,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 183,
#   'lastUpdateEt': '4/18 13:08',
#   'checkTimeEt': '4/18 14:58',
#   'death': 9,
#   'hospitalized': 47,
#   'total': 12963,
#   'totalTestResults': 12963,
#   'posNeg': 12963,
#   'fips': '38',
#   'dateModified': '2020-04-18T17:08:00Z',
#   'dateChecked': '2020-04-18T18:58:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'b80ea5bbe0056756a85c2f85e25efb3f44a09e0d'},
#  {'state': 'NE',
#   'positive': 1287,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 13288,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 19:45',
#   'checkTimeEt': '4/18 23:40',
#   'death': 28,
#   'hospitalized': None,
#   'total': 14575,
#   'totalTestResults': 14575,
#   'posNeg': 14575,
#   'fips': '31',
#   'dateModified': '2020-04-18T23:45:00Z',
#   'dateChecked': '2020-04-19T03:40:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '1d283bdd7ee8a5ac5e3f3d9f3aa7aa4cfe457f2f'},
#  {'state': 'NH',
#   'positive': 1342,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 0,
#   'grade': 'B',
#   'score': 3,
#   'negative': 12082,
#   'pending': 316,
#   'hospitalizedCurrently': 85,
#   'hospitalizedCumulative': 192,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 513,
#   'lastUpdateEt': '4/18 09:00',
#   'checkTimeEt': '4/18 23:35',
#   'death': 38,
#   'hospitalized': 192,
#   'total': 13740,
#   'totalTestResults': 13424,
#   'posNeg': 13424,
#   'fips': '33',
#   'dateModified': '2020-04-18T13:00:00Z',
#   'dateChecked': '2020-04-19T03:35:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'da7f6eade74e30619d94b86063b3b5ac0958b7a0'},
#  {'state': 'NJ',
#   'positive': 81420,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 81116,
#   'pending': None,
#   'hospitalizedCurrently': 7718,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2024,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 1641,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 12:49',
#   'checkTimeEt': '4/18 14:40',
#   'death': 4070,
#   'hospitalized': None,
#   'total': 162536,
#   'totalTestResults': 162536,
#   'posNeg': 162536,
#   'fips': '34',
#   'dateModified': '2020-04-18T16:49:00Z',
#   'dateChecked': '2020-04-18T18:40:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '5f0a2edce4840348269340e3191501f63cd2f4df'},
#  {'state': 'NM',
#   'positive': 1798,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 34834,
#   'pending': None,
#   'hospitalizedCurrently': 92,
#   'hospitalizedCumulative': 258,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 465,
#   'lastUpdateEt': '4/18 18:00',
#   'checkTimeEt': '4/18 23:36',
#   'death': 53,
#   'hospitalized': 258,
#   'total': 36632,
#   'totalTestResults': 36632,
#   'posNeg': 36632,
#   'fips': '35',
#   'dateModified': '2020-04-18T22:00:00Z',
#   'dateChecked': '2020-04-19T03:36:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'd8b2f4843d6bdc0bb0e9959e2e2ee89d489f74a5'},
#  {'state': 'NV',
#   'positive': 3626,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 27125,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 19:00',
#   'checkTimeEt': '4/18 23:33',
#   'death': 155,
#   'hospitalized': None,
#   'total': 30751,
#   'totalTestResults': 30751,
#   'posNeg': 30751,
#   'fips': '32',
#   'dateModified': '2020-04-18T23:00:00Z',
#   'dateChecked': '2020-04-19T03:33:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '7eb7e6a56dfe97ce40622ec63580868aa56e6757'},
#  {'state': 'NY',
#   'positive': 236732,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 359800,
#   'pending': None,
#   'hospitalizedCurrently': 16967,
#   'hospitalizedCumulative': 54339,
#   'inIcuCurrently': 5016,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 23887,
#   'lastUpdateEt': '4/18 00:00',
#   'checkTimeEt': '4/18 23:59',
#   'death': 13362,
#   'hospitalized': 54339,
#   'total': 596532,
#   'totalTestResults': 596532,
#   'posNeg': 596532,
#   'fips': '36',
#   'dateModified': '2020-04-18T04:00:00Z',
#   'dateChecked': '2020-04-19T03:59:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '92ee6dc4b173c977d5d7d1122d4e9a8422a361b2'},
#  {'state': 'OH',
#   'positive': 9939,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 0,
#   'commercialScore': 1,
#   'grade': 'B',
#   'score': 3,
#   'negative': 68819,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 2519,
#   'inIcuCurrently': None,
#   'inIcuCumulative': 760,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 14:00',
#   'checkTimeEt': '4/18 14:04',
#   'death': 451,
#   'hospitalized': 2519,
#   'total': 78758,
#   'totalTestResults': 78758,
#   'posNeg': 78758,
#   'fips': '39',
#   'dateModified': '2020-04-18T18:00:00Z',
#   'dateChecked': '2020-04-18T18:04:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'b497f6567d23e38f41d3c8a3b6b02fb0fcfc2358'},
#  {'state': 'OK',
#   'positive': 2570,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 0,
#   'commercialScore': 1,
#   'grade': 'B',
#   'score': 3,
#   'negative': 32966,
#   'pending': None,
#   'hospitalizedCurrently': 307,
#   'hospitalizedCumulative': 541,
#   'inIcuCurrently': 136,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 1515,
#   'lastUpdateEt': '4/18 00:00',
#   'checkTimeEt': '4/18 14:30',
#   'death': 139,
#   'hospitalized': 541,
#   'total': 35536,
#   'totalTestResults': 35536,
#   'posNeg': 35536,
#   'fips': '40',
#   'dateModified': '2020-04-18T04:00:00Z',
#   'dateChecked': '2020-04-18T18:30:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '547c9be21442cdbc336151896ac401b2b5067ad0'},
#  {'state': 'OR',
#   'positive': 1844,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 35739,
#   'pending': None,
#   'hospitalizedCurrently': 290,
#   'hospitalizedCumulative': 449,
#   'inIcuCurrently': 74,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 37,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 11:00',
#   'checkTimeEt': '4/18 16:07',
#   'death': 72,
#   'hospitalized': 449,
#   'total': 37583,
#   'totalTestResults': 37583,
#   'posNeg': 37583,
#   'fips': '41',
#   'dateModified': '2020-04-18T15:00:00Z',
#   'dateChecked': '2020-04-18T20:07:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '37509c0dfb3f468099cede13dbdd1d73c0e47be2'},
#  {'state': 'PA',
#   'positive': 31069,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 122896,
#   'pending': None,
#   'hospitalizedCurrently': 2613,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 660,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 12:00',
#   'checkTimeEt': '4/18 14:10',
#   'death': 836,
#   'hospitalized': None,
#   'total': 153965,
#   'totalTestResults': 153965,
#   'posNeg': 153965,
#   'fips': '42',
#   'dateModified': '2020-04-18T16:00:00Z',
#   'dateChecked': '2020-04-18T18:10:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '44413d63687cbb8cbcc8089a8f3f70fca1d29c71'},
#  {'state': 'RI',
#   'positive': 4491,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 0,
#   'grade': 'B',
#   'score': 3,
#   'negative': 28335,
#   'pending': None,
#   'hospitalizedCurrently': 255,
#   'hospitalizedCumulative': 331,
#   'inIcuCurrently': 67,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 43,
#   'onVentilatorCumulative': None,
#   'recovered': 217,
#   'lastUpdateEt': '4/18 12:00',
#   'checkTimeEt': '4/18 15:07',
#   'death': 137,
#   'hospitalized': 331,
#   'total': 32826,
#   'totalTestResults': 32826,
#   'posNeg': 32826,
#   'fips': '44',
#   'dateModified': '2020-04-18T16:00:00Z',
#   'dateChecked': '2020-04-18T19:07:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '05f99aaf45fc8aab0df84dbd3568affce4ae42f1'},
#  {'state': 'SC',
#   'positive': 4246,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 0,
#   'grade': 'B',
#   'score': 3,
#   'negative': 34587,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 776,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 2633,
#   'lastUpdateEt': '4/18 15:25',
#   'checkTimeEt': '4/18 16:05',
#   'death': 119,
#   'hospitalized': 776,
#   'total': 38833,
#   'totalTestResults': 38833,
#   'posNeg': 38833,
#   'fips': '45',
#   'dateModified': '2020-04-18T19:25:00Z',
#   'dateChecked': '2020-04-18T20:05:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'd589ccce8cfc11090570620eb6436719426aa25e'},
#  {'state': 'SD',
#   'positive': 1542,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 10118,
#   'pending': 1,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 68,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 552,
#   'lastUpdateEt': '4/17 18:00',
#   'checkTimeEt': '4/18 22:38',
#   'death': 7,
#   'hospitalized': 68,
#   'total': 11661,
#   'totalTestResults': 11660,
#   'posNeg': 11660,
#   'fips': '46',
#   'dateModified': '2020-04-17T22:00:00Z',
#   'dateChecked': '2020-04-19T02:38:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'e52119f0711a228af5674edbaba459cf673cc027'},
#  {'state': 'TN',
#   'positive': 6762,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 83824,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 719,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 3234,
#   'lastUpdateEt': '4/18 15:00',
#   'checkTimeEt': '4/18 15:52',
#   'death': 145,
#   'hospitalized': 719,
#   'total': 90586,
#   'totalTestResults': 90586,
#   'posNeg': 90586,
#   'fips': '47',
#   'dateModified': '2020-04-18T19:00:00Z',
#   'dateChecked': '2020-04-18T19:52:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '78a980cd87fc81d3b2a87f2d73f461eadc4e36bc'},
#  {'state': 'TX',
#   'positive': 18260,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 157979,
#   'pending': None,
#   'hospitalizedCurrently': 1321,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 4806,
#   'lastUpdateEt': '4/18 13:45',
#   'checkTimeEt': '4/18 14:17',
#   'death': 453,
#   'hospitalized': None,
#   'total': 176239,
#   'totalTestResults': 176239,
#   'posNeg': 176239,
#   'fips': '48',
#   'dateModified': '2020-04-18T17:45:00Z',
#   'dateChecked': '2020-04-18T18:17:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '1b58166f90f053bdc11fe14744f708b84e9f608c'},
#  {'state': 'UT',
#   'positive': 2931,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 57013,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 251,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 565,
#   'lastUpdateEt': '4/18 15:00',
#   'checkTimeEt': '4/18 14:11',
#   'death': 25,
#   'hospitalized': 251,
#   'total': 59944,
#   'totalTestResults': 59944,
#   'posNeg': 59944,
#   'fips': '49',
#   'dateModified': '2020-04-18T19:00:00Z',
#   'dateChecked': '2020-04-18T18:11:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'c634cf1548d743714f207df648052596548d0d2a'},
#  {'state': 'VA',
#   'positive': 8053,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 43878,
#   'pending': 486,
#   'hospitalizedCurrently': 1307,
#   'hospitalizedCumulative': 1296,
#   'inIcuCurrently': 398,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 230,
#   'onVentilatorCumulative': None,
#   'recovered': 1228,
#   'lastUpdateEt': '4/17 17:00',
#   'checkTimeEt': '4/18 22:30',
#   'death': 258,
#   'hospitalized': 1296,
#   'total': 52417,
#   'totalTestResults': 51931,
#   'posNeg': 51931,
#   'fips': '51',
#   'dateModified': '2020-04-17T21:00:00Z',
#   'dateChecked': '2020-04-19T02:30:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'fcb0f3d51c64375d5695a823712ccd2d652b3672'},
#  {'state': 'VT',
#   'positive': 803,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 11763,
#   'pending': None,
#   'hospitalizedCurrently': 56,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 15,
#   'lastUpdateEt': '4/18 09:50',
#   'checkTimeEt': '4/18 14:21',
#   'death': 38,
#   'hospitalized': None,
#   'total': 12566,
#   'totalTestResults': 12566,
#   'posNeg': 12566,
#   'fips': '50',
#   'dateModified': '2020-04-18T13:50:00Z',
#   'dateChecked': '2020-04-18T18:21:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'feee9551da41e923177d3dd14834a6c22049afaf'},
#  {'state': 'WA',
#   'positive': 11802,
#   'positiveScore': 0,
#   'negativeScore': 1,
#   'negativeRegularScore': 0,
#   'commercialScore': 1,
#   'grade': 'C',
#   'score': 2,
#   'negative': 123904,
#   'pending': None,
#   'hospitalizedCurrently': 586,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 193,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 02:59',
#   'checkTimeEt': '4/18 23:22',
#   'death': 624,
#   'hospitalized': None,
#   'total': 135706,
#   'totalTestResults': 135706,
#   'posNeg': 135706,
#   'fips': '53',
#   'dateModified': '2020-04-18T06:59:00Z',
#   'dateChecked': '2020-04-19T03:22:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'afe7b64c8c7908a8d6f80374e4e76de533d9019a'},
#  {'state': 'WI',
#   'positive': 4199,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 43962,
#   'pending': 229,
#   'hospitalizedCurrently': 361,
#   'hospitalizedCumulative': 1176,
#   'inIcuCurrently': 135,
#   'inIcuCumulative': 307,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 12:45',
#   'checkTimeEt': '4/18 15:37',
#   'death': 211,
#   'hospitalized': 1176,
#   'total': 48390,
#   'totalTestResults': 48161,
#   'posNeg': 48161,
#   'fips': '55',
#   'dateModified': '2020-04-18T16:45:00Z',
#   'dateChecked': '2020-04-18T19:37:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '86043869d26406ad8a7fd7d05ab9fa9d56c780d1'},
#  {'state': 'WV',
#   'positive': 825,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 0,
#   'grade': 'B',
#   'score': 3,
#   'negative': 18969,
#   'pending': None,
#   'hospitalizedCurrently': 72,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 37,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 25,
#   'onVentilatorCumulative': None,
#   'recovered': 265,
#   'lastUpdateEt': '4/18 17:00',
#   'checkTimeEt': '4/18 23:57',
#   'death': 18,
#   'hospitalized': None,
#   'total': 19794,
#   'totalTestResults': 19794,
#   'posNeg': 19794,
#   'fips': '54',
#   'dateModified': '2020-04-18T21:00:00Z',
#   'dateChecked': '2020-04-19T03:57:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '78019af3262d346573aa02e201817ef78d4085d3'},
#  {'state': 'WY',
#   'positive': 309,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 6972,
#   'pending': None,
#   'hospitalizedCurrently': 19,
#   'hospitalizedCumulative': 50,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 227,
#   'lastUpdateEt': '4/18 14:20',
#   'checkTimeEt': '4/18 23:13',
#   'death': 2,
#   'hospitalized': 50,
#   'total': 7281,
#   'totalTestResults': 7281,
#   'posNeg': 7281,
#   'fips': '56',
#   'dateModified': '2020-04-18T18:20:00Z',
#   'dateChecked': '2020-04-19T03:13:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '3bc1e5cc0d97aab43948f11450a3164616ea4a0e'},
#  {'state': 'PR',
#   'positive': 1118,
#   'positiveScore': 1,
#   'negativeScore': 1,
#   'negativeRegularScore': 1,
#   'commercialScore': 1,
#   'grade': 'A',
#   'score': 4,
#   'negative': 8055,
#   'pending': 1760,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/18 07:00',
#   'checkTimeEt': '4/18 22:42',
#   'death': 60,
#   'hospitalized': None,
#   'total': 10933,
#   'totalTestResults': 9173,
#   'posNeg': 9173,
#   'fips': '72',
#   'dateModified': '2020-04-18T11:00:00Z',
#   'dateChecked': '2020-04-19T02:42:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '5e7cc12e9547a78dbd5d2c83bbad071010dcde05'},
#  {'state': 'AS',
#   'positive': 0,
#   'negative': 3,
#   'pending': 17,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'lastUpdateEt': '4/06 00:00',
#   'checkTimeEt': '4/18 15:35',
#   'death': None,
#   'hospitalized': None,
#   'total': 20,
#   'totalTestResults': 3,
#   'posNeg': 3,
#   'fips': '60',
#   'dateModified': '2020-04-06T04:00:00Z',
#   'dateChecked': '2020-04-18T19:35:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '34543c1d9e023ff07c911e2a3c30514e79de44ac'},
#  {'state': 'GU',
#   'positive': 136,
#   'negative': 943,
#   'pending': None,
#   'hospitalizedCurrently': 6,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 110,
#   'lastUpdateEt': '4/18 06:50',
#   'checkTimeEt': '4/18 15:45',
#   'death': 5,
#   'hospitalized': None,
#   'total': 1079,
#   'totalTestResults': 1079,
#   'posNeg': 1079,
#   'fips': '66',
#   'dateModified': '2020-04-18T10:50:00Z',
#   'dateChecked': '2020-04-18T19:45:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': '4f647d2f9c72f364e71b786c722587b54c4b5051'},
#  {'state': 'MP',
#   'positive': 14,
#   'negative': 42,
#   'pending': 4,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 9,
#   'lastUpdateEt': '4/17 19:15',
#   'checkTimeEt': '4/18 15:55',
#   'death': 2,
#   'hospitalized': None,
#   'total': 60,
#   'totalTestResults': 56,
#   'posNeg': 56,
#   'fips': '69',
#   'dateModified': '2020-04-17T23:15:00Z',
#   'dateChecked': '2020-04-18T19:55:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'a598f7ab4d054ecbcf925b2ca22cc88d92c8bf52'},
#  {'state': 'VI',
#   'positive': 53,
#   'negative': 548,
#   'pending': 22,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 48,
#   'lastUpdateEt': '4/18 20:30',
#   'checkTimeEt': '4/18 23:23',
#   'death': 3,
#   'hospitalized': None,
#   'total': 623,
#   'totalTestResults': 601,
#   'posNeg': 601,
#   'fips': '78',
#   'dateModified': '2020-04-19T00:30:00Z',
#   'dateChecked': '2020-04-19T03:23:00Z',
#   'notes': 'Please stop using the "total" field. Use "totalTestResults" instead.',
#   'hash': 'fa3bc0bd70bffc84078608cbd7e3a6992b91c831'}]

# %%
US_df = json_normalize(response.json(), errors='ignore')
US_df
# Out:
#    state  positive  positiveScore  negativeScore  negativeRegularScore  \
# 0     AK       314            1.0            1.0                   1.0
# 1     AL      4723            1.0            1.0                   0.0
# 2     AR      1777            1.0            1.0                   1.0
# 3     AZ      4719            1.0            1.0                   0.0
# 4     CA     28963            1.0            1.0                   0.0
# 5     CO      9433            1.0            1.0                   1.0
# 6     CT     17550            1.0            1.0                   1.0
# 7     DC      2666            1.0            1.0                   1.0
# 8     DE      2538            1.0            1.0                   1.0
# 9     FL     25492            1.0            1.0                   1.0
# 10    GA     17841            1.0            1.0                   1.0
# 11    HI       564            1.0            1.0                   1.0
# 12    IA      2513            1.0            1.0                   1.0
# 13    ID      1668            1.0            1.0                   1.0
# 14    IL     29160            1.0            1.0                   1.0
# 15    IN     10641            1.0            1.0                   1.0
# 16    KS      1790            1.0            1.0                   1.0
# 17    KY      2707            1.0            1.0                   1.0
# 18    LA     23580            1.0            1.0                   1.0
# 19    MA     36372            1.0            1.0                   0.0
# 20    MD     12308            1.0            1.0                   1.0
# 21    ME       847            1.0            1.0                   1.0
# 22    MI     30791            1.0            1.0                   0.0
# 23    MN      2213            1.0            1.0                   1.0
# 24    MO      5517            1.0            1.0                   1.0
# 25    MS      3974            1.0            1.0                   1.0
# 26    MT       426            1.0            1.0                   1.0
# 27    NC      6140            1.0            1.0                   1.0
# 28    ND       528            1.0            1.0                   1.0
# 29    NE      1287            1.0            1.0                   1.0
# 30    NH      1342            1.0            1.0                   1.0
# 31    NJ     81420            1.0            1.0                   1.0
# 32    NM      1798            1.0            1.0                   1.0
# 33    NV      3626            1.0            1.0                   1.0
# 34    NY    236732            1.0            1.0                   1.0
# 35    OH      9939            1.0            1.0                   0.0
# 36    OK      2570            1.0            1.0                   0.0
# 37    OR      1844            1.0            1.0                   1.0
# 38    PA     31069            1.0            1.0                   1.0
# 39    RI      4491            1.0            1.0                   1.0
# 40    SC      4246            1.0            1.0                   1.0
# 41    SD      1542            1.0            1.0                   1.0
# 42    TN      6762            1.0            1.0                   1.0
# 43    TX     18260            1.0            1.0                   1.0
# 44    UT      2931            1.0            1.0                   1.0
# 45    VA      8053            1.0            1.0                   1.0
# 46    VT       803            1.0            1.0                   1.0
# 47    WA     11802            0.0            1.0                   0.0
# 48    WI      4199            1.0            1.0                   1.0
# 49    WV       825            1.0            1.0                   1.0
# 50    WY       309            1.0            1.0                   1.0
# 51    PR      1118            1.0            1.0                   1.0
# 52    AS         0            NaN            NaN                   NaN
# 53    GU       136            NaN            NaN                   NaN
# 54    MP        14            NaN            NaN                   NaN
# 55    VI        53            NaN            NaN                   NaN
#
#     commercialScore grade  score  negative  pending  ...    death  \
# 0               1.0     A    4.0      9341      NaN  ...      9.0
# 1               1.0     B    3.0     37883      NaN  ...    147.0
# 2               1.0     A    4.0     22428      NaN  ...     38.0
# 3               1.0     B    3.0     46326      NaN  ...    177.0
# 4               1.0     B    3.0    230703   7200.0  ...   1072.0
# 5               1.0     A    4.0     35173      NaN  ...    411.0
# 6               1.0     A    4.0     40663      NaN  ...   1086.0
# 7               1.0     A    4.0     10602      NaN  ...     91.0
# 8               1.0     A    4.0     12256      NaN  ...     67.0
# 9               1.0     A    4.0    225862   1214.0  ...    765.0
# 10              1.0     A    4.0     56539      NaN  ...    677.0
# 11              1.0     A    4.0     22896      NaN  ...      9.0
# 12              1.0     A    4.0     20434      NaN  ...     74.0
# 13              1.0     A    4.0     15201      NaN  ...     44.0
# 14              1.0     A    4.0    108244      NaN  ...   1259.0
# 15              0.0     B    3.0     46232      NaN  ...    545.0
# 16              0.0     B    3.0     15886      NaN  ...     86.0
# 17              1.0     A    4.0     29518      NaN  ...    144.0
# 18              1.0     A    4.0    114419      NaN  ...   1267.0
# 19              1.0     B    3.0    120434      NaN  ...   1560.0
# 20              1.0     A    4.0     53062      NaN  ...    463.0
# 21              1.0     A    4.0     14076      NaN  ...     32.0
# 22              1.0     B    3.0     73233      NaN  ...   2308.0
# 23              1.0     A    4.0     42055      NaN  ...    121.0
# 24              1.0     A    4.0     48242      NaN  ...    175.0
# 25              1.0     A    4.0     34791      NaN  ...    152.0
# 26              1.0     A    4.0     10143      NaN  ...     10.0
# 27              1.0     A    4.0     70071      NaN  ...    164.0
# 28              0.0     B    3.0     12435      NaN  ...      9.0
# 29              1.0     A    4.0     13288      NaN  ...     28.0
# 30              0.0     B    3.0     12082    316.0  ...     38.0
# 31              1.0     A    4.0     81116      NaN  ...   4070.0
# 32              1.0     A    4.0     34834      NaN  ...     53.0
# 33              1.0     A    4.0     27125      NaN  ...    155.0
# 34              1.0     A    4.0    359800      NaN  ...  13362.0
# 35              1.0     B    3.0     68819      NaN  ...    451.0
# 36              1.0     B    3.0     32966      NaN  ...    139.0
# 37              1.0     A    4.0     35739      NaN  ...     72.0
# 38              1.0     A    4.0    122896      NaN  ...    836.0
# 39              0.0     B    3.0     28335      NaN  ...    137.0
# 40              0.0     B    3.0     34587      NaN  ...    119.0
# 41              1.0     A    4.0     10118      1.0  ...      7.0
# 42              1.0     A    4.0     83824      NaN  ...    145.0
# 43              1.0     A    4.0    157979      NaN  ...    453.0
# 44              1.0     A    4.0     57013      NaN  ...     25.0
# 45              1.0     A    4.0     43878    486.0  ...    258.0
# 46              1.0     A    4.0     11763      NaN  ...     38.0
# 47              1.0     C    2.0    123904      NaN  ...    624.0
# 48              1.0     A    4.0     43962    229.0  ...    211.0
# 49              0.0     B    3.0     18969      NaN  ...     18.0
# 50              1.0     A    4.0      6972      NaN  ...      2.0
# 51              1.0     A    4.0      8055   1760.0  ...     60.0
# 52              NaN   NaN    NaN         3     17.0  ...      NaN
# 53              NaN   NaN    NaN       943      NaN  ...      5.0
# 54              NaN   NaN    NaN        42      4.0  ...      2.0
# 55              NaN   NaN    NaN       548     22.0  ...      3.0
#
#     hospitalized   total  totalTestResults  posNeg  fips  \
# 0           36.0    9655              9655    9655    02
# 1          620.0   42606             42606   42606    01
# 2          291.0   24205             24205   24205    05
# 3            NaN   51045             51045   51045    04
# 4            NaN  266866            259666  259666    06
# 5         1797.0   44606             44606   44606    08
# 6            NaN   58213             58213   58213    09
# 7            NaN   13268             13268   13268    11
# 8            NaN   14794             14794   14794    10
# 9         3908.0  252568            251354  251354    12
# 10        3447.0   74380             74380   74380    13
# 11          51.0   23460             23460   23460    15
# 12           NaN   22947             22947   22947    19
# 13         151.0   16869             16869   16869    16
# 14           NaN  137404            137404  137404    17
# 15           NaN   56873             56873   56873    18
# 16         383.0   17676             17676   17676    20
# 17        1059.0   32225             32225   32225    21
# 18           NaN  137999            137999  137999    22
# 19           NaN  156806            156806  156806    25
# 20        2757.0   65370             65370   65370    24
# 21         136.0   14923             14923   14923    23
# 22           NaN  104024            104024  104024    26
# 23         561.0   44268             44268   44268    27
# 24           NaN   53759             53759   53759    29
# 25         782.0   38765             38765   38765    28
# 26          55.0   10569             10569   10569    30
# 27           NaN   76211             76211   76211    37
# 28          47.0   12963             12963   12963    38
# 29           NaN   14575             14575   14575    31
# 30         192.0   13740             13424   13424    33
# 31           NaN  162536            162536  162536    34
# 32         258.0   36632             36632   36632    35
# 33           NaN   30751             30751   30751    32
# 34       54339.0  596532            596532  596532    36
# 35        2519.0   78758             78758   78758    39
# 36         541.0   35536             35536   35536    40
# 37         449.0   37583             37583   37583    41
# 38           NaN  153965            153965  153965    42
# 39         331.0   32826             32826   32826    44
# 40         776.0   38833             38833   38833    45
# 41          68.0   11661             11660   11660    46
# 42         719.0   90586             90586   90586    47
# 43           NaN  176239            176239  176239    48
# 44         251.0   59944             59944   59944    49
# 45        1296.0   52417             51931   51931    51
# 46           NaN   12566             12566   12566    50
# 47           NaN  135706            135706  135706    53
# 48        1176.0   48390             48161   48161    55
# 49           NaN   19794             19794   19794    54
# 50          50.0    7281              7281    7281    56
# 51           NaN   10933              9173    9173    72
# 52           NaN      20                 3       3    60
# 53           NaN    1079              1079    1079    66
# 54           NaN      60                56      56    69
# 55           NaN     623               601     601    78
#
#             dateModified           dateChecked  \
# 0   2020-04-18T18:15:00Z  2020-04-18T19:09:00Z
# 1   2020-04-18T04:00:00Z  2020-04-19T02:13:00Z
# 2   2020-04-18T19:41:00Z  2020-04-19T03:24:00Z
# 3   2020-04-18T04:00:00Z  2020-04-18T19:25:00Z
# 4   2020-04-17T04:00:00Z  2020-04-18T22:52:00Z
# 5   2020-04-18T04:00:00Z  2020-04-19T02:26:00Z
# 6   2020-04-18T04:00:00Z  2020-04-19T02:42:00Z
# 7   2020-04-17T04:00:00Z  2020-04-18T19:29:00Z
# 8   2020-04-18T21:00:00Z  2020-04-19T02:44:00Z
# 9   2020-04-18T20:24:00Z  2020-04-19T02:46:00Z
# 10  2020-04-18T22:28:00Z  2020-04-19T02:54:00Z
# 11  2020-04-18T22:30:00Z  2020-04-19T03:38:00Z
# 12  2020-04-17T16:00:00Z  2020-04-19T03:18:00Z
# 13  2020-04-18T23:00:00Z  2020-04-19T03:13:00Z
# 14  2020-04-18T04:00:00Z  2020-04-18T20:05:00Z
# 15  2020-04-18T03:59:00Z  2020-04-18T19:54:00Z
# 16  2020-04-18T16:00:00Z  2020-04-18T19:55:00Z
# 17  2020-04-18T21:00:00Z  2020-04-19T02:45:00Z
# 18  2020-04-18T17:00:00Z  2020-04-18T19:20:00Z
# 19  2020-04-18T14:00:00Z  2020-04-19T03:13:00Z
# 20  2020-04-18T14:00:00Z  2020-04-18T19:41:00Z
# 21  2020-04-18T19:00:00Z  2020-04-18T20:05:00Z
# 22  2020-04-18T15:00:00Z  2020-04-19T03:49:00Z
# 23  2020-04-17T21:00:00Z  2020-04-18T19:53:00Z
# 24  2020-04-18T19:00:00Z  2020-04-18T19:45:00Z
# 25  2020-04-17T23:00:00Z  2020-04-19T03:37:00Z
# 26  2020-04-18T14:18:00Z  2020-04-18T19:34:00Z
# 27  2020-04-18T15:00:00Z  2020-04-18T18:56:00Z
# 28  2020-04-18T17:08:00Z  2020-04-18T18:58:00Z
# 29  2020-04-18T23:45:00Z  2020-04-19T03:40:00Z
# 30  2020-04-18T13:00:00Z  2020-04-19T03:35:00Z
# 31  2020-04-18T16:49:00Z  2020-04-18T18:40:00Z
# 32  2020-04-18T22:00:00Z  2020-04-19T03:36:00Z
# 33  2020-04-18T23:00:00Z  2020-04-19T03:33:00Z
# 34  2020-04-18T04:00:00Z  2020-04-19T03:59:00Z
# 35  2020-04-18T18:00:00Z  2020-04-18T18:04:00Z
# 36  2020-04-18T04:00:00Z  2020-04-18T18:30:00Z
# 37  2020-04-18T15:00:00Z  2020-04-18T20:07:00Z
# 38  2020-04-18T16:00:00Z  2020-04-18T18:10:00Z
# 39  2020-04-18T16:00:00Z  2020-04-18T19:07:00Z
# 40  2020-04-18T19:25:00Z  2020-04-18T20:05:00Z
# 41  2020-04-17T22:00:00Z  2020-04-19T02:38:00Z
# 42  2020-04-18T19:00:00Z  2020-04-18T19:52:00Z
# 43  2020-04-18T17:45:00Z  2020-04-18T18:17:00Z
# 44  2020-04-18T19:00:00Z  2020-04-18T18:11:00Z
# 45  2020-04-17T21:00:00Z  2020-04-19T02:30:00Z
# 46  2020-04-18T13:50:00Z  2020-04-18T18:21:00Z
# 47  2020-04-18T06:59:00Z  2020-04-19T03:22:00Z
# 48  2020-04-18T16:45:00Z  2020-04-18T19:37:00Z
# 49  2020-04-18T21:00:00Z  2020-04-19T03:57:00Z
# 50  2020-04-18T18:20:00Z  2020-04-19T03:13:00Z
# 51  2020-04-18T11:00:00Z  2020-04-19T02:42:00Z
# 52  2020-04-06T04:00:00Z  2020-04-18T19:35:00Z
# 53  2020-04-18T10:50:00Z  2020-04-18T19:45:00Z
# 54  2020-04-17T23:15:00Z  2020-04-18T19:55:00Z
# 55  2020-04-19T00:30:00Z  2020-04-19T03:23:00Z
#
#                                                 notes  \
# 0   Please stop using the "total" field. Use "tota...
# 1   Please stop using the "total" field. Use "tota...
# 2   Please stop using the "total" field. Use "tota...
# 3   Please stop using the "total" field. Use "tota...
# 4   Please stop using the "total" field. Use "tota...
# 5   Please stop using the "total" field. Use "tota...
# 6   Please stop using the "total" field. Use "tota...
# 7   Please stop using the "total" field. Use "tota...
# 8   Please stop using the "total" field. Use "tota...
# 9   Please stop using the "total" field. Use "tota...
# 10  Please stop using the "total" field. Use "tota...
# 11  Please stop using the "total" field. Use "tota...
# 12  Please stop using the "total" field. Use "tota...
# 13  Please stop using the "total" field. Use "tota...
# 14  Please stop using the "total" field. Use "tota...
# 15  Please stop using the "total" field. Use "tota...
# 16  Please stop using the "total" field. Use "tota...
# 17  Please stop using the "total" field. Use "tota...
# 18  Please stop using the "total" field. Use "tota...
# 19  Please stop using the "total" field. Use "tota...
# 20  Please stop using the "total" field. Use "tota...
# 21  Please stop using the "total" field. Use "tota...
# 22  Please stop using the "total" field. Use "tota...
# 23  Please stop using the "total" field. Use "tota...
# 24  Please stop using the "total" field. Use "tota...
# 25  Please stop using the "total" field. Use "tota...
# 26  Please stop using the "total" field. Use "tota...
# 27  Please stop using the "total" field. Use "tota...
# 28  Please stop using the "total" field. Use "tota...
# 29  Please stop using the "total" field. Use "tota...
# 30  Please stop using the "total" field. Use "tota...
# 31  Please stop using the "total" field. Use "tota...
# 32  Please stop using the "total" field. Use "tota...
# 33  Please stop using the "total" field. Use "tota...
# 34  Please stop using the "total" field. Use "tota...
# 35  Please stop using the "total" field. Use "tota...
# 36  Please stop using the "total" field. Use "tota...
# 37  Please stop using the "total" field. Use "tota...
# 38  Please stop using the "total" field. Use "tota...
# 39  Please stop using the "total" field. Use "tota...
# 40  Please stop using the "total" field. Use "tota...
# 41  Please stop using the "total" field. Use "tota...
# 42  Please stop using the "total" field. Use "tota...
# 43  Please stop using the "total" field. Use "tota...
# 44  Please stop using the "total" field. Use "tota...
# 45  Please stop using the "total" field. Use "tota...
# 46  Please stop using the "total" field. Use "tota...
# 47  Please stop using the "total" field. Use "tota...
# 48  Please stop using the "total" field. Use "tota...
# 49  Please stop using the "total" field. Use "tota...
# 50  Please stop using the "total" field. Use "tota...
# 51  Please stop using the "total" field. Use "tota...
# 52  Please stop using the "total" field. Use "tota...
# 53  Please stop using the "total" field. Use "tota...
# 54  Please stop using the "total" field. Use "tota...
# 55  Please stop using the "total" field. Use "tota...
#
#                                         hash
# 0   363f0fd82439b801b085e6b3371f7655b02592b8
# 1   d9a1b4e0f0d5c2ce4470c5e29fe02b1df29639ff
# 2   a2a34e8451646d52aec40d914139d14c4e2ea4e3
# 3   6f5351e769c581777aba8523f997e8eed562fbea
# 4   a185c582ec6d052ead9b88a7e5a25c27cad4d89d
# 5   9c71664393c1015491ec091ee9889072dde7f46e
# 6   eb95a8804158fd9b1b8bc83c216f4d9454eededb
# 7   9836e127cfb29ac8dbd92f24dc653538b6bfdde8
# 8   f04002498da1e046967738d1cc25f933c7348553
# 9   346f0224af1eb35378b5d5775d7945de11cb4c95
# 10  58e7ffc117a671b25b2d8596ce8eb55b6d2b510f
# 11  419d1c73d2e7925904611eb5217dd0b9fb70f4e7
# 12  5d758eaa20327eb15ef331808f71bf4b9b39532e
# 13  0d1d9be44fb4aa32d6237c8e5055f9b4d20d1d6c
# 14  09ee6ac31c1657d678fca17cac336d47d7b2d075
# 15  f8aec48409289ca99b70a4f7ef1d9d669a7e01b8
# 16  5e2b1cbbd2905df3a6e35c1648312d4ac6a0d333
# 17  8c3e8b53fae63be4828cf699ed1a09bada075fca
# 18  50e8242e1e7cd1c3d7bc2505e4b63ef969705dce
# 19  e990b1957b32867af7948c348e147387448813b6
# 20  3a0b174064e41d533defe0fd755eb87ef21ef8d6
# 21  e441a363c8ff01cce71271a910319eecd7cc3cec
# 22  05d84522edfbd01f4dc3b5eb56ad90d10fb41973
# 23  b4745a2b1feb726deb4eae44a12199ac5ece84be
# 24  f5194aab86d3029664dbea985288de14c30b7d89
# 25  44f219854c697b0a6c331790c81b551c0ddfc9c0
# 26  f5b6442dcdb019acb044863abb3995f60027b805
# 27  232e1d026f04f30e61ae91a1c8b7079fe0186a58
# 28  b80ea5bbe0056756a85c2f85e25efb3f44a09e0d
# 29  1d283bdd7ee8a5ac5e3f3d9f3aa7aa4cfe457f2f
# 30  da7f6eade74e30619d94b86063b3b5ac0958b7a0
# 31  5f0a2edce4840348269340e3191501f63cd2f4df
# 32  d8b2f4843d6bdc0bb0e9959e2e2ee89d489f74a5
# 33  7eb7e6a56dfe97ce40622ec63580868aa56e6757
# 34  92ee6dc4b173c977d5d7d1122d4e9a8422a361b2
# 35  b497f6567d23e38f41d3c8a3b6b02fb0fcfc2358
# 36  547c9be21442cdbc336151896ac401b2b5067ad0
# 37  37509c0dfb3f468099cede13dbdd1d73c0e47be2
# 38  44413d63687cbb8cbcc8089a8f3f70fca1d29c71
# 39  05f99aaf45fc8aab0df84dbd3568affce4ae42f1
# 40  d589ccce8cfc11090570620eb6436719426aa25e
# 41  e52119f0711a228af5674edbaba459cf673cc027
# 42  78a980cd87fc81d3b2a87f2d73f461eadc4e36bc
# 43  1b58166f90f053bdc11fe14744f708b84e9f608c
# 44  c634cf1548d743714f207df648052596548d0d2a
# 45  fcb0f3d51c64375d5695a823712ccd2d652b3672
# 46  feee9551da41e923177d3dd14834a6c22049afaf
# 47  afe7b64c8c7908a8d6f80374e4e76de533d9019a
# 48  86043869d26406ad8a7fd7d05ab9fa9d56c780d1
# 49  78019af3262d346573aa02e201817ef78d4085d3
# 50  3bc1e5cc0d97aab43948f11450a3164616ea4a0e
# 51  5e7cc12e9547a78dbd5d2c83bbad071010dcde05
# 52  34543c1d9e023ff07c911e2a3c30514e79de44ac
# 53  4f647d2f9c72f364e71b786c722587b54c4b5051
# 54  a598f7ab4d054ecbcf925b2ca22cc88d92c8bf52
# 55  fa3bc0bd70bffc84078608cbd7e3a6992b91c831
#
# [56 rows x 29 columns]

# %%
US_df.iloc[:,[0,1,8,22]]
# Out:
#    state  positive  negative  totalTestResults
# 0     AK       314      9341              9655
# 1     AL      4723     37883             42606
# 2     AR      1777     22428             24205
# 3     AZ      4719     46326             51045
# 4     CA     28963    230703            259666
# 5     CO      9433     35173             44606
# 6     CT     17550     40663             58213
# 7     DC      2666     10602             13268
# 8     DE      2538     12256             14794
# 9     FL     25492    225862            251354
# 10    GA     17841     56539             74380
# 11    HI       564     22896             23460
# 12    IA      2513     20434             22947
# 13    ID      1668     15201             16869
# 14    IL     29160    108244            137404
# 15    IN     10641     46232             56873
# 16    KS      1790     15886             17676
# 17    KY      2707     29518             32225
# 18    LA     23580    114419            137999
# 19    MA     36372    120434            156806
# 20    MD     12308     53062             65370
# 21    ME       847     14076             14923
# 22    MI     30791     73233            104024
# 23    MN      2213     42055             44268
# 24    MO      5517     48242             53759
# 25    MS      3974     34791             38765
# 26    MT       426     10143             10569
# 27    NC      6140     70071             76211
# 28    ND       528     12435             12963
# 29    NE      1287     13288             14575
# 30    NH      1342     12082             13424
# 31    NJ     81420     81116            162536
# 32    NM      1798     34834             36632
# 33    NV      3626     27125             30751
# 34    NY    236732    359800            596532
# 35    OH      9939     68819             78758
# 36    OK      2570     32966             35536
# 37    OR      1844     35739             37583
# 38    PA     31069    122896            153965
# 39    RI      4491     28335             32826
# 40    SC      4246     34587             38833
# 41    SD      1542     10118             11660
# 42    TN      6762     83824             90586
# 43    TX     18260    157979            176239
# 44    UT      2931     57013             59944
# 45    VA      8053     43878             51931
# 46    VT       803     11763             12566
# 47    WA     11802    123904            135706
# 48    WI      4199     43962             48161
# 49    WV       825     18969             19794
# 50    WY       309      6972              7281
# 51    PR      1118      8055              9173
# 52    AS         0         3                 3
# 53    GU       136       943              1079
# 54    MP        14        42                56
# 55    VI        53       548               601

# %% [markdown]
# DATAFRAMES
# -----------------------
# SHWETA:
#
# Global_DF
#
# Combined_Countries_DF
#
# ALL_US_DF

# %%
Global_DF = pd.DataFrame(Global_df)
Global_DF
# Out:
#      cases  deaths  recovered
# 0  2358256  161902     606630

# %%
Combined_Countries_DF = pd.DataFrame(Countries_df.iloc[:,[0,1,2,3,4,5,6,]])
Combined_Countries_DF
# Out:
#            country    cases  todayCases  deaths  todayDeaths  recovered  \
# 0    North America   792769        1363   41670          133    83535.0
# 1           Europe  1079650       19614  100794         1516   305791.0
# 2             Asia   376860        6076   14593          192   178315.0
# 3    South America    78207         234    3665           12    27698.0
# 4          Oceania     8134          29      82            1     5159.0
# ..             ...      ...         ...     ...          ...        ...
# 222         Total:   376860        6076   14593          192   178315.0
# 223         Total:    78207         234    3665           12    27698.0
# 224         Total:     8134          29      82            1     5159.0
# 225         Total:    21915         174    1083            1     5488.0
# 226         Total:      721           0      15            0      644.0
#
#      active
# 0    667564
# 1    673065
# 2    183952
# 3     46844
# 4      2893
# ..      ...
# 222  183952
# 223   46844
# 224    2893
# 225   15344
# 226      62
#
# [227 rows x 7 columns]

# %%
ALL_US_DF = pd.DataFrame(US_df.iloc[:,[0,1,8,22]])
ALL_US_DF
# Out:
#    state  positive  negative  totalTestResults
# 0     AK       314      9341              9655
# 1     AL      4723     37883             42606
# 2     AR      1777     22428             24205
# 3     AZ      4719     46326             51045
# 4     CA     28963    230703            259666
# 5     CO      9433     35173             44606
# 6     CT     17550     40663             58213
# 7     DC      2666     10602             13268
# 8     DE      2538     12256             14794
# 9     FL     25492    225862            251354
# 10    GA     17841     56539             74380
# 11    HI       564     22896             23460
# 12    IA      2513     20434             22947
# 13    ID      1668     15201             16869
# 14    IL     29160    108244            137404
# 15    IN     10641     46232             56873
# 16    KS      1790     15886             17676
# 17    KY      2707     29518             32225
# 18    LA     23580    114419            137999
# 19    MA     36372    120434            156806
# 20    MD     12308     53062             65370
# 21    ME       847     14076             14923
# 22    MI     30791     73233            104024
# 23    MN      2213     42055             44268
# 24    MO      5517     48242             53759
# 25    MS      3974     34791             38765
# 26    MT       426     10143             10569
# 27    NC      6140     70071             76211
# 28    ND       528     12435             12963
# 29    NE      1287     13288             14575
# 30    NH      1342     12082             13424
# 31    NJ     81420     81116            162536
# 32    NM      1798     34834             36632
# 33    NV      3626     27125             30751
# 34    NY    236732    359800            596532
# 35    OH      9939     68819             78758
# 36    OK      2570     32966             35536
# 37    OR      1844     35739             37583
# 38    PA     31069    122896            153965
# 39    RI      4491     28335             32826
# 40    SC      4246     34587             38833
# 41    SD      1542     10118             11660
# 42    TN      6762     83824             90586
# 43    TX     18260    157979            176239
# 44    UT      2931     57013             59944
# 45    VA      8053     43878             51931
# 46    VT       803     11763             12566
# 47    WA     11802    123904            135706
# 48    WI      4199     43962             48161
# 49    WV       825     18969             19794
# 50    WY       309      6972              7281
# 51    PR      1118      8055              9173
# 52    AS         0         3                 3
# 53    GU       136       943              1079
# 54    MP        14        42                56
# 55    VI        53       548               601
