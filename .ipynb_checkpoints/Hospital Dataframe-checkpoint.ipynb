# %%
import csv
import os
import pandas as pd
from pprint import pprint

#read in .csv file
hospital_data = pd.read_csv("../hospitals.csv")

#set index to state_name
hospital_data.set_index("state_name",inplace=True)

#group dataframe by state_name
hg = hospital_data.groupby('state_name')

#do count of hg dataframe (where it groups by states)to get total count of hospitals, doctors, staff,
#icu beds, and icu beds utilized. Then add each series to new dataframe called 'state_hospital_data'

hg["num_icu_be"].count()
state_hospital_data = pd.DataFrame(hg["num_icu_be"].count())

hospitals = hg["hospital_n"].count()
state_hospital_data["Number of Hospitals"]=hospitals

doctors = hg["num_licens"].count()
state_hospital_data["Number of Doctors"]=doctors

staff = hg["num_staffe"].count()
state_hospital_data["Number of Staff"]=staff

icu_beds = hg["num_icu_be"].count()
state_hospital_data["ICU Beds Available"]=icu_beds

bed_utiliz = hg["bed_utiliz"].count()
state_hospital_data["ICU Beds Utilized"]=bed_utiliz

#drop double num_icu_be column
state_hospital_data.drop("num_icu_be",axis=1)

#final data frame
state_hospital_data
# Out:
#                       num_icu_be  Number of Hospitals  Number of Doctors  \
# state_name
# Alabama                       66                  120                120
# Alaska                         7                   28                 28
# Arizona                       46                  126                126
# Arkansas                      40                  106                106
# California                   302                  466                466
# Colorado                      48                  113                113
# Connecticut                   25                   46                 46
# Delaware                       5                   16                 16
# District of Columbia           6                   14                 14
# Florida                      172                  276                276
# Georgia                       87                  180                180
# Hawaii                        14                   29                 29
# Idaho                         15                   53                 53
# Illinois                     118                  215                215
# Indiana                       81                  177                177
# Iowa                          35                  124                124
# Kansas                        41                  164                164
# Kentucky                      65                  119                119
# Louisiana                     66                  221                221
# Maine                         19                   39                 39
# Maryland                      43                   66                 66
# Massachusetts                 51                  110                110
# Michigan                      88                  171                171
# Minnesota                     47                  148                148
# Mississippi                   38                  114                114
# Missouri                      66                  151                151
# Montana                       16                   67                 67
# Nebraska                      19                  101                101
# Nevada                        23                   67                 67
# New Hampshire                 17                   34                 34
# New Jersey                    62                  101                101
# New Mexico                    26                   57                 57
# New York                     127                  230                230
# North Carolina                82                  145                145
# North Dakota                   8                   54                 54
# Ohio                         122                  251                251
# Oklahoma                      45                  157                157
# Oregon                        38                   69                 69
# Pennsylvania                 125                  246                246
# Puerto Rico                   36                   50                 50
# Rhode Island                   8                   15                 15
# South Carolina                52                   93                 93
# South Dakota                  13                   66                 66
# Tennessee                     68                  149                149
# Texas                        222                  644                644
# Utah                          27                   62                 62
# Vermont                        7                   17                 17
# Virginia                      68                  124                124
# Washington                    50                  116                116
# West Virginia                 28                   67                 67
# Wisconsin                     72                  150                150
# Wyoming                       11                   33                 33
#
#                       Number of Staff  ICU Beds Available  ICU Beds Utilized
# state_name
# Alabama                           120                  66                109
# Alaska                             28                   7                 23
# Arizona                           126                  46                108
# Arkansas                          106                  40                100
# California                        466                 302                401
# Colorado                          113                  48                101
# Connecticut                        46                  25                 40
# Delaware                           16                   5                 15
# District of Columbia               14                   6                 12
# Florida                           276                 172                250
# Georgia                           180                  87                164
# Hawaii                             29                  14                 23
# Idaho                              53                  15                 47
# Illinois                          215                 118                199
# Indiana                           177                  81                161
# Iowa                              124                  35                121
# Kansas                            164                  41                147
# Kentucky                          119                  65                112
# Louisiana                         221                  66                202
# Maine                              39                  19                 38
# Maryland                           66                  43                 58
# Massachusetts                     110                  51                 96
# Michigan                          171                  88                161
# Minnesota                         148                  47                139
# Mississippi                       114                  38                106
# Missouri                          151                  66                134
# Montana                            67                  16                 65
# Nebraska                          101                  19                 98
# Nevada                             67                  23                 55
# New Hampshire                      34                  17                 30
# New Jersey                        101                  62                 95
# New Mexico                         57                  26                 54
# New York                          230                 127                197
# North Carolina                    145                  82                128
# North Dakota                       54                   8                 49
# Ohio                              251                 122                225
# Oklahoma                          157                  45                142
# Oregon                             69                  38                 62
# Pennsylvania                      246                 125                219
# Puerto Rico                        50                  36                 44
# Rhode Island                       15                   8                 13
# South Carolina                     93                  52                 79
# South Dakota                       66                  13                 60
# Tennessee                         149                  68                138
# Texas                             644                 222                554
# Utah                               62                  27                 56
# Vermont                            17                   7                 16
# Virginia                          124                  68                109
# Washington                        116                  50                101
# West Virginia                      67                  28                 58
# Wisconsin                         150                  72                144
# Wyoming                            33                  11                 29
