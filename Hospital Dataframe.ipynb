# %%
import csv
import os
import pandas as pd
from pprint import pprint

# %%
#read in .csv file
hospital_csv = os.path.join("hospitals.csv")

hospital_data = pd.read_csv(hospital_csv)
hospital_data.head()
#hospital_data.describe()
# Out:
#           objectid    hq_zip_cod   state_fips   cnty_fips          fips  \
# count  6581.000000   6581.000000  6557.000000  6557.00000   6557.000000
# mean   3291.000000  53832.454794    29.264908    94.35443  29359.262163
# std    1899.915393  27239.010857    16.082085   106.19441  16108.043571
# min       1.000000    603.000000     1.000000     1.00000   1001.000000
# 25%    1646.000000  32320.000000    17.000000    29.00000  17031.000000
# 50%    3291.000000  55350.000000    29.000000    69.00000  29049.000000
# 75%    4936.000000  76384.000000    42.000000   119.00000  42101.000000
# max    6581.000000  99929.000000    72.000000   840.00000  72153.000000
#
#         num_icu_be   bed_utiliz    potential
# count  2977.000000  5904.000000  6581.000000
# mean     21.649647     0.492613    19.847744
# std      22.629819     0.235245    64.903458
# min       1.000000     0.000721  -834.000000
# 25%       8.000000     0.301759     0.000000
# 50%      15.000000     0.498840     0.000000
# ...

# %%
print()
