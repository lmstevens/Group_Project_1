# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from pprint import pprint

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {'Subscription-Key': '011f81d005ea4ecfbea6df39bd8433ce'}

params = urllib.parse.urlencode({ })
params
# Out:
# ''

# %%
params = urllib.parse.urlencode({ })


conn.request("GET", "?%s" % params, headers)
response = conn.getresponse()
data = response.read()
print(data)
conn.close()

# %%
response = requests.get("https://api.smartable.ai/coronavirus/stats/US-NC HTTP/1.1Cache-Control: no-cacheSubscription-Key: 011f81d005ea4ecfbea6df39bd8433ce").json()
pprint(response)
# Out:
# {'message': 'Resource not found', 'statusCode': 404}

# %%
import requests

url = "https://thevirustracker.com/free-api?countryTimeline=US"

payload = {}
headers= {}

response = requests.get("https://thevirustracker.com/free-api?countryTimeline=US")
#data= response.json()
print(response)

response.content
# Out:
# <Response [200]>
# b''

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
# Request headers
'Subscription-Key': '011f81d005ea4ecfbea6df39bd8433ce',
}

params = urllib.parse.urlencode({https://developer.smartable.ai/api-details#api=coronavirus&operation=stats
})

try:
conn.request("GET", "?%s" % params, headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
#   File "<ipython-input-16-57db2fffcd48>", line 8
#     params = urllib.parse.urlencode({https://developer.smartable.ai/api-details#api=coronavirus&operation=stats
#                                             ^
# SyntaxError: invalid syntax

# %%
# Retrieving all countries data, converting it into JSON and Printing the output of the JSON
response = requests.get(url2).json()
print(json.dumps(response, indent=4, sort_keys=True))

# %%
# URL for GET requests to retrieve global count data
url1 = "https://coronavirus-19-api.herokuapp.com/all"
# URL for GET requests to retrieve all countries data
url2 = "https://coronavirus-19-api.herokuapp.com/countries"

# Retrieving global data, converting it into JSON and Printing the output of the JSON
response = requests.get(url2).json()
pprint(response)
# Out:
# [{'active': 597957,
#   'cases': 689094,
#   'casesPerOneMillion': 0,
#   'country': 'North America',
#   'critical': 14595,
#   'deaths': 30420,
#   'deathsPerOneMillion': 0,
#   'recovered': 60717,
#   'testsPerOneMillion': 0,
#   'todayCases': 450,
#   'todayDeaths': 43,
#   'totalTests': 0},
#  {'active': 624472,
#   'cases': 970757,
#   'casesPerOneMillion': 0,
#   'country': 'Europe',
#   'critical': 28603,
#   'deaths': 88319,
#   'deathsPerOneMillion': 0,
#   'recovered': 257966,
#   'testsPerOneMillion': 0,
#   'todayCases': 0,
#   'todayDeaths': 0,
#   'totalTests': 0},
#  {'active': 161060,
#   'cases': 333197,
#   'casesPerOneMillion': 0,
#   'country': 'Asia',
#   'critical': 6478,
#   'deaths': 12068,
#   'deathsPerOneMillion': 0,
#   'recovered': 160069,
#   'testsPerOneMillion': 0,
#   'todayCases': 0,
#   'todayDeaths': 0,
#   'totalTests': 0},
#  {'active': 38127,
#   'cases': 63302,
#   'casesPerOneMillion': 0,
#   'country': 'South America',
#   'critical': 1218,
# ...

# %%
countries = ["North America", "USA", "Europe", "Asia", "South America", "Africa"]
# set up lists to hold reponse info
active = []
cases = []
critical = []
deaths = []
recovered = []
todayCases = []
todayDeaths = []
# Loop through the list of countries and perform a request for data on each
for i in range(len(response)):
    if response[i]["country"] in countries:
        active.append(response[i]["active"])
    else:
        print(response[i]["country"])
# Out:
# Oceania
#
# World
# Spain
# Italy
# France
# Germany
# UK
# Iran
# Turkey
# Belgium
# Brazil
# Canada
# Netherlands
# Switzerland
# Russia
# Portugal
# Austria
# Ireland
# Israel
# India
# Sweden
# Peru
# S. Korea
# Japan
# Chile
# Ecuador
# Poland
# Romania
# Norway
# Denmark
# Australia
# Pakistan
# Czechia
# Saudi Arabia
# Mexico
# Philippines
# UAE
# Indonesia
# Malaysia
# Serbia
# Ukraine
# Panama
# Belarus
# Qatar
# Singapore
# Dominican Republic
# Luxembourg
# Finland
# Colombia
# Thailand
# Argentina
# South Africa
# Egypt
# Greece
# Algeria
# Moldova
# Morocco
# Croatia
# Iceland
# Bahrain
# Hungary
# Iraq
# Kuwait
# Estonia
# New Zealand
# Uzbekistan
# Kazakhstan
# Azerbaijan
# Slovenia
# Bangladesh
# Armenia
# Bosnia and Herzegovina
# Lithuania
# Hong Kong
# North Macedonia
# Oman
# Slovakia
# Cameroon
# Cuba
# Afghanistan
# Tunisia
# Bulgaria
# Cyprus
# Diamond Princess
# Andorra
# Latvia
# Lebanon
# Ivory Coast
# Ghana
# Costa Rica
# Niger
# Burkina Faso
# Albania
# ...

# %%
active
# Out:
# [597957, 624472, 161060, 38127, 13052, 566859]

# %%
df = pd.DataFrame({"Countries":countries,"Active Cases":active})
df
# Out:
#        Countries  Active Cases
# 0  North America        597957
# 1            USA        624472
# 2         Europe        161060
# 3           Asia         38127
# 4  South America         13052
# 5         Africa        566859

# %%
   active.append(response['active'])
    cases.append(response['cases'])
    critical.append(response['critical'])
    deaths.append(response['deaths'])
    recovered.append(response['recovered'])
    todayCases.append(response['todayCases'])
    todayDeaths.append(response['todayDeaths'])

# %%
url = "https://covid-19-live-stats.p.rapidapi.com/newcasesbydate"

headers = {
    'x-rapidapi-host': "covid-19-live-stats.p.rapidapi.com",
    'x-rapidapi-key': "97d9c19a4dmsh213e2f86d7f9509p1f07d5jsn2ae24daa08fa"
    }

response = requests.get(url, headers=headers).json()

pprint(response)
# Out:
# [{'cases': 85568, 'date': '2020-04-09T00:00:00.000Z'},
#  {'cases': 84385, 'date': '2020-04-08T00:00:00.000Z'},
#  {'cases': 85074, 'date': '2020-04-07T00:00:00.000Z'},
#  {'cases': 73135, 'date': '2020-04-06T00:00:00.000Z'},
#  {'cases': 71418, 'date': '2020-04-05T00:00:00.000Z'},
#  {'cases': 84821, 'date': '2020-04-04T00:00:00.000Z'},
#  {'cases': 101566, 'date': '2020-04-03T00:00:00.000Z'},
#  {'cases': 79864, 'date': '2020-04-02T00:00:00.000Z'},
#  {'cases': 76871, 'date': '2020-04-01T00:00:00.000Z'},
#  {'cases': 73620, 'date': '2020-03-31T00:00:00.000Z'},
#  {'cases': 61351, 'date': '2020-03-30T00:00:00.000Z'},
#  {'cases': 60263, 'date': '2020-03-29T00:00:00.000Z'},
#  {'cases': 66761, 'date': '2020-03-28T00:00:00.000Z'},
#  {'cases': 64501, 'date': '2020-03-27T00:00:00.000Z'},
#  {'cases': 60830, 'date': '2020-03-26T00:00:00.000Z'},
#  {'cases': 48461, 'date': '2020-03-25T00:00:00.000Z'},
#  {'cases': 43744, 'date': '2020-03-24T00:00:00.000Z'},
# ...

# %%
df = pd.read_csv()
